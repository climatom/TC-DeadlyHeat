# %% [markdown]
# # TC-Impact on Met: Weather Stations
#
# Here we search the GSOD for weather stations near TC landfall to assess the impact of TC passage on the surface meteorology.
#
# The idea is to search for the nearest station that has ALL data present for landfall +/-30 days, and has at least k % completion for j years, and l % completion for the period +/- landfall within that ten-year period

# %%
import ulmo as ul, numpy as np, pandas as pd,TC_Utils as tc, \
GeneralFunctions as GF, datetime as datetime, matplotlib.pyplot as plt, os, pickle
from netCDF4 import Dataset
# Out:
# /home/lunet/gytm3/anaconda2/lib/python2.7/site-packages/ulmo/twc/kbdi/core.py:20: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   CSV_SWITCHOVER = pandas.tslib.Timestamp('2016-10-01')

# %%
# Set parameters
minlen=10 # years of observations
minpc=70 # percentage complete over minlen period
maxdist=197 # maximum distance to search away from the TC (radius to 12 m/s wind [Chavas and Emmanuel, 2010])
min_frac=50.0 # GSOD Data be at least this complete to count as "complete (over 1981-2010)"
stdev=15/1.96

# Open the obs file (with landfall locations)
# strcture is: ID	YEAR	JD.JD	LAT	LON	GLAT	GLON	ROW	COL	DIST
tcdata=np.loadtxt("/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/LandFall.txt",delimiter="\t",skiprows=1)

# Pull out landfall lat/lon
tclat=tcdata[:,3]; tclon=tcdata[:,4]
# Set the output file name. It will be a log with ID | LAT | LON | STATION ID | Distance
outfile="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/GSOD_Stations.txt"
outfile_silver="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/GSOD_Stations_silver.txt"
# Set the output directory to write the "complete GSOD data to"
odir="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/GSOD_Complete/"
odir_silver="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/GSOD_Passage/"
# Directory to write test files to
testdir="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/Testing/"

# %%
# Use ulmo to return meta data on ALL stations with data since 1979
all_stations=ul.ncdc.gsod.get_stations(start="1979-01-01 00:00:00")

# %%
all_stations["113580-99999"]["latitude"]
# Out:
# 47.55

# %% [markdown]
# ## Find stations that are close enough to TC landfall (within maxdist) and have SLP & HI data for the TC landfall dat (+/- 30 days)

# %%
# Use ulmo-modified code to extract met data for the station nearest the TC landfall
reload(tc)
ids=all_stations.keys() # station codes
latlon=np.array([[all_stations[ii]["latitude"],all_stations[ii]["longitude"]] for ii in ids],dtype=np.float) # coordinates
# Test now by extracting pressure 
outmet=[]
outmet_hit=[]
out_station=[]
dist_used=np.zeros((len(tcdata)))*np.nan
nsuc=0
with open(outfile,"w") as fo:
    
    # Write the header to the output file
    fo.write("YEAR\tMONTH\tDAY\tID\tLAT\tLON\tSTATION_ID\tDIST\n")
    
    for loc in range(len(tcdata)):

        # If all criteria are met, we'll not search any more; initialise to "search"
        dist=GF.haversine_fast(tclat[loc],tclon[loc],latlon[:,0],latlon[:,1],miles=False) # that's the distance
        order=np.argsort(dist)
        nearest=0
        mindist=dist[order[nearest]]
        keep_search=True
        while keep_search and mindist<maxdist:

            # Construct date index for this landfall location
            tc_date=datetime.date(year=int(tcdata[loc,1]),month=1,day=1)+datetime.timedelta(days=tcdata[loc,2]-1)
            tc_st=tc_date-datetime.timedelta(days=30)
            tc_end=tc_date+datetime.timedelta(days=30)

            # Now extract all data for the year (+/-1) of TC landfall for the station closest to landfall location
            startyr=tc_date.year-1; endyr=tc_date.year+1
            alldata,corevars=tc.get_gsod_data("/media/gytm3/WD12TB/GSOD",\
            [ids[order[nearest]],],startyr=int(startyr), endyr=int(endyr), parameters=None)

            # Check we have something!
            if len(corevars)>1:     

                # Compute HI. etc
                corevars["tempC"]=GF.Faren2C(corevars["mean_temp"])
                corevars["dewC"]=GF.Faren2C(corevars["dew_point"])
                corevars["rh"]=GF.dewVp(corevars["dewC"]+273.15)/GF.satVp(corevars["tempC"])*100.            
                corevars["specHum"]=GF.specHum(corevars["tempC"],corevars["rh"],corevars["slp"])
                corevars["hi"]=GF.HeatIndexNWS(corevars["tempC"],corevars["rh"],opt=False,iounit=np.array([0,0]))

                # Check for completion during "hit"
                hit_data=corevars[tc_st:tc_end]

                # Examine pressure and hi
                # Note these ranges should be constrained based on GSOD meta-data
                n_press=np.sum(np.logical_and(hit_data["slp"]!=9999.9,hit_data["slp"]!=9999.9))
                n_hi=np.sum(np.logical_and(hit_data["hi"]>-100,hit_data["hi"]<200))

                # Then all data here
                if n_press == 61 and n_hi == 61:
                    outmet.append(corevars)
                    outmet_hit.append(hit_data)
                    dist_used[loc]=dist[order[nearest]]
                    out_station.append(ids[order[nearest]])

                    # End search
                    keep_search=False; print "Found what we're after! [dist=%.1f; station=%s]" \
                    % (dist[order[nearest]],ids[order[nearest]])
                    nsuc+=1
                    
                    # Write a new line out
                    lout="%.0f\t%.0f\t%.0f\t%.0f\t%.2f\t%.2f\t%s\t%.2f\n" % \
                    (tc_date.year,tc_date.month,tc_date.day,\
                     tcdata[loc,0],tcdata[loc,3],tcdata[loc,4],ids[order[nearest]],dist[order[nearest]])
                    fo.write(lout); fo.flush()

            if keep_search:
                mindist=dist[order[nearest+1]]
                print "Didn't satisfy criteria [dist=%.1f]; moving to distance: %.1f" % \
                    (dist[order[nearest]],mindist)


            nearest+=1  
        print "Finished with loc %.0f" % loc
# Out:
# Didn't satisfy criteria [dist=67.8]; moving to distance: 133.0
# Didn't satisfy criteria [dist=133.0]; moving to distance: 134.1
# Didn't satisfy criteria [dist=134.1]; moving to distance: 214.2
# Finished with loc 0
# Didn't satisfy criteria [dist=14.5]; moving to distance: 16.4
# Didn't satisfy criteria [dist=16.4]; moving to distance: 99.5
# Didn't satisfy criteria [dist=99.5]; moving to distance: 103.3
# Didn't satisfy criteria [dist=103.3]; moving to distance: 194.2
# Didn't satisfy criteria [dist=194.2]; moving to distance: 225.0
# Finished with loc 1
# Didn't satisfy criteria [dist=57.5]; moving to distance: 89.3
# Didn't satisfy criteria [dist=89.3]; moving to distance: 122.7
# Didn't satisfy criteria [dist=122.7]; moving to distance: 123.6
# Didn't satisfy criteria [dist=123.6]; moving to distance: 159.5
# Didn't satisfy criteria [dist=159.5]; moving to distance: 167.5
# Didn't satisfy criteria [dist=167.5]; moving to distance: 189.3
# Didn't satisfy criteria [dist=189.3]; moving to distance: 218.6
# Finished with loc 2
# Didn't satisfy criteria [dist=30.3]; moving to distance: 73.5
# Didn't satisfy criteria [dist=73.5]; moving to distance: 117.9
# Didn't satisfy criteria [dist=117.9]; moving to distance: 128.9
# Didn't satisfy criteria [dist=128.9]; moving to distance: 146.5
# Didn't satisfy criteria [dist=146.5]; moving to distance: 247.6
# Finished with loc 3
# Didn't satisfy criteria [dist=34.0]; moving to distance: 98.0
# Didn't satisfy criteria [dist=98.0]; moving to distance: 110.5
# Didn't satisfy criteria [dist=110.5]; moving to distance: 124.8
# Didn't satisfy criteria [dist=124.8]; moving to distance: 125.3
# Didn't satisfy criteria [dist=125.3]; moving to distance: 205.5
# Finished with loc 4
# Didn't satisfy criteria [dist=35.2]; moving to distance: 86.8
# Didn't satisfy criteria [dist=86.8]; moving to distance: 127.5
# Didn't satisfy criteria [dist=127.5]; moving to distance: 145.6
# Didn't satisfy criteria [dist=145.6]; moving to distance: 157.5
# Didn't satisfy criteria [dist=157.5]; moving to distance: 171.9
# Didn't satisfy criteria [dist=171.9]; moving to distance: 211.4
# Finished with loc 5
# Didn't satisfy criteria [dist=65.7]; moving to distance: 67.4
# Didn't satisfy criteria [dist=67.4]; moving to distance: 118.1
# Didn't satisfy criteria [dist=118.1]; moving to distance: 176.2
# Didn't satisfy criteria [dist=176.2]; moving to distance: 178.4
# Didn't satisfy criteria [dist=178.4]; moving to distance: 183.7
# Didn't satisfy criteria [dist=183.7]; moving to distance: 201.7
# Finished with loc 6
# Didn't satisfy criteria [dist=60.5]; moving to distance: 92.6
# Didn't satisfy criteria [dist=92.6]; moving to distance: 113.2
# Didn't satisfy criteria [dist=113.2]; moving to distance: 131.2
# Didn't satisfy criteria [dist=131.2]; moving to distance: 159.3
# Didn't satisfy criteria [dist=159.3]; moving to distance: 228.0
# Finished with loc 7
# Didn't satisfy criteria [dist=3.4]; moving to distance: 4.9
# Didn't satisfy criteria [dist=4.9]; moving to distance: 5.4
# Didn't satisfy criteria [dist=5.4]; moving to distance: 5.9
# Didn't satisfy criteria [dist=5.9]; moving to distance: 6.2
# Didn't satisfy criteria [dist=6.2]; moving to distance: 16.3
# Didn't satisfy criteria [dist=16.3]; moving to distance: 16.3
# Didn't satisfy criteria [dist=16.3]; moving to distance: 16.7
# Didn't satisfy criteria [dist=16.7]; moving to distance: 30.4
# Found what we're after! [dist=30.4; station=722500-12919]
# Finished with loc 8
# Found what we're after! [dist=39.8; station=595590-99999]
# Finished with loc 9
# Didn't satisfy criteria [dist=31.1]; moving to distance: 36.0
# Didn't satisfy criteria [dist=36.0]; moving to distance: 60.1
# Didn't satisfy criteria [dist=60.1]; moving to distance: 81.5
# Didn't satisfy criteria [dist=81.5]; moving to distance: 95.9
# Didn't satisfy criteria [dist=95.9]; moving to distance: 114.5
# Found what we're after! [dist=114.5; station=983280-99999]
# Finished with loc 10
# Didn't satisfy criteria [dist=59.5]; moving to distance: 120.9
# Didn't satisfy criteria [dist=120.9]; moving to distance: 121.8
# Didn't satisfy criteria [dist=121.8]; moving to distance: 133.5
# Didn't satisfy criteria [dist=133.5]; moving to distance: 199.8
# Finished with loc 11
# Didn't satisfy criteria [dist=15.8]; moving to distance: 16.0
# Didn't satisfy criteria [dist=16.0]; moving to distance: 64.7
# Didn't satisfy criteria [dist=64.7]; moving to distance: 80.5
# Didn't satisfy criteria [dist=80.5]; moving to distance: 81.0
# Didn't satisfy criteria [dist=81.0]; moving to distance: 117.8
# Didn't satisfy criteria [dist=117.8]; moving to distance: 131.7
# Didn't satisfy criteria [dist=131.7]; moving to distance: 152.3
# Didn't satisfy criteria [dist=152.3]; moving to distance: 158.2
# Didn't satisfy criteria [dist=158.2]; moving to distance: 166.8
# Didn't satisfy criteria [dist=166.8]; moving to distance: 167.2
# Didn't satisfy criteria [dist=167.2]; moving to distance: 192.4
# Didn't satisfy criteria [dist=192.4]; moving to distance: 198.6
# Finished with loc 12
# Didn't satisfy criteria [dist=45.4]; moving to distance: 65.8
# Didn't satisfy criteria [dist=65.8]; moving to distance: 66.9
# Didn't satisfy criteria [dist=66.9]; moving to distance: 161.7
# Didn't satisfy criteria [dist=161.7]; moving to distance: 162.2
# Found what we're after! [dist=162.2; station=982230-99999]
# Finished with loc 13
# Found what we're after! [dist=23.6; station=467610-99999]
# Finished with loc 14
# Didn't satisfy criteria [dist=51.4]; moving to distance: 113.6
# Didn't satisfy criteria [dist=113.6]; moving to distance: 166.1
# Didn't satisfy criteria [dist=166.1]; moving to distance: 192.4
# Didn't satisfy criteria [dist=192.4]; moving to distance: 203.8
# Finished with loc 15
# Didn't satisfy criteria [dist=16.1]; moving to distance: 138.1
# Didn't satisfy criteria [dist=138.1]; moving to distance: 148.0
# Didn't satisfy criteria [dist=148.0]; moving to distance: 187.7
# Didn't satisfy criteria [dist=187.7]; moving to distance: 213.3
# Finished with loc 16
# Didn't satisfy criteria [dist=66.7]; moving to distance: 155.0
# Didn't satisfy criteria [dist=155.0]; moving to distance: 167.2
# Didn't satisfy criteria [dist=167.2]; moving to distance: 195.9
# Didn't satisfy criteria [dist=195.9]; moving to distance: 197.9
# Finished with loc 17
# Didn't satisfy criteria [dist=81.8]; moving to distance: 94.6
# Didn't satisfy criteria [dist=94.6]; moving to distance: 96.1
# Didn't satisfy criteria [dist=96.1]; moving to distance: 109.2
# Didn't satisfy criteria [dist=109.2]; moving to distance: 111.5
# Didn't satisfy criteria [dist=111.5]; moving to distance: 139.5
# Didn't satisfy criteria [dist=139.5]; moving to distance: 140.2
# Didn't satisfy criteria [dist=140.2]; moving to distance: 154.1
# Didn't satisfy criteria [dist=154.1]; moving to distance: 154.6
# Didn't satisfy criteria [dist=154.6]; moving to distance: 179.9
# Didn't satisfy criteria [dist=179.9]; moving to distance: 187.8
# Didn't satisfy criteria [dist=187.8]; moving to distance: 191.9
# Didn't satisfy criteria [dist=191.9]; moving to distance: 203.5
# Finished with loc 18
# Didn't satisfy criteria [dist=35.6]; moving to distance: 62.7
# Didn't satisfy criteria [dist=62.7]; moving to distance: 63.6
# Didn't satisfy criteria [dist=63.6]; moving to distance: 79.8
# Didn't satisfy criteria [dist=79.8]; moving to distance: 88.1
# Didn't satisfy criteria [dist=88.1]; moving to distance: 109.3
# Didn't satisfy criteria [dist=109.3]; moving to distance: 109.5
# Didn't satisfy criteria [dist=109.5]; moving to distance: 117.2
# Didn't satisfy criteria [dist=117.2]; moving to distance: 158.3
# Didn't satisfy criteria [dist=158.3]; moving to distance: 158.4
# Didn't satisfy criteria [dist=158.4]; moving to distance: 160.7
# Didn't satisfy criteria [dist=160.7]; moving to distance: 165.5
# Didn't satisfy criteria [dist=165.5]; moving to distance: 170.7
# Didn't satisfy criteria [dist=170.7]; moving to distance: 171.0
# Didn't satisfy criteria [dist=171.0]; moving to distance: 172.8
# Didn't satisfy criteria [dist=172.8]; moving to distance: 204.3
# Finished with loc 19
# Didn't satisfy criteria [dist=61.7]; moving to distance: 65.2
# Didn't satisfy criteria [dist=65.2]; moving to distance: 67.1
# Didn't satisfy criteria [dist=67.1]; moving to distance: 77.9
# Didn't satisfy criteria [dist=77.9]; moving to distance: 111.4
# Didn't satisfy criteria [dist=111.4]; moving to distance: 113.0
# Didn't satisfy criteria [dist=113.0]; moving to distance: 120.0
# Didn't satisfy criteria [dist=120.0]; moving to distance: 140.6
# Didn't satisfy criteria [dist=140.6]; moving to distance: 140.8
# Didn't satisfy criteria [dist=140.8]; moving to distance: 151.5
# Didn't satisfy criteria [dist=151.5]; moving to distance: 190.6
# Didn't satisfy criteria [dist=190.6]; moving to distance: 198.2
# Finished with loc 20
# Didn't satisfy criteria [dist=18.6]; moving to distance: 71.5
# Didn't satisfy criteria [dist=71.5]; moving to distance: 71.9
# Didn't satisfy criteria [dist=71.9]; moving to distance: 90.4
# Didn't satisfy criteria [dist=90.4]; moving to distance: 92.1
# Didn't satisfy criteria [dist=92.1]; moving to distance: 95.7
# Didn't satisfy criteria [dist=95.7]; moving to distance: 98.0
# Found what we're after! [dist=98.0; station=984400-99999]
# Finished with loc 21
# Didn't satisfy criteria [dist=109.8]; moving to distance: 111.5
# Didn't satisfy criteria [dist=111.5]; moving to distance: 120.9
# Didn't satisfy criteria [dist=120.9]; moving to distance: 168.9
# Didn't satisfy criteria [dist=168.9]; moving to distance: 225.8
# Finished with loc 22
# Didn't satisfy criteria [dist=21.0]; moving to distance: 21.3
# Didn't satisfy criteria [dist=21.3]; moving to distance: 21.5
# Didn't satisfy criteria [dist=21.5]; moving to distance: 21.5
# Didn't satisfy criteria [dist=21.5]; moving to distance: 22.1
# Didn't satisfy criteria [dist=22.1]; moving to distance: 37.9
# Didn't satisfy criteria [dist=37.9]; moving to distance: 37.9
# Didn't satisfy criteria [dist=37.9]; moving to distance: 39.6
# Didn't satisfy criteria [dist=39.6]; moving to distance: 39.6
# Didn't satisfy criteria [dist=39.6]; moving to distance: 125.0
# Didn't satisfy criteria [dist=125.0]; moving to distance: 150.7
# Didn't satisfy criteria [dist=150.7]; moving to distance: 167.2
# Didn't satisfy criteria [dist=167.2]; moving to distance: 202.3
# Finished with loc 23
# Didn't satisfy criteria [dist=48.1]; moving to distance: 73.2
# Didn't satisfy criteria [dist=73.2]; moving to distance: 97.1
# Didn't satisfy criteria [dist=97.1]; moving to distance: 97.9
# Didn't satisfy criteria [dist=97.9]; moving to distance: 97.9
# Didn't satisfy criteria [dist=97.9]; moving to distance: 98.1
# Didn't satisfy criteria [dist=98.1]; moving to distance: 98.2
# Didn't satisfy criteria [dist=98.2]; moving to distance: 99.8
# Didn't satisfy criteria [dist=99.8]; moving to distance: 99.8
# Didn't satisfy criteria [dist=99.8]; moving to distance: 100.3
# Didn't satisfy criteria [dist=100.3]; moving to distance: 101.3
# Didn't satisfy criteria [dist=101.3]; moving to distance: 150.7
# Didn't satisfy criteria [dist=150.7]; moving to distance: 193.2
# Found what we're after! [dist=193.2; station=766440-99999]
# Finished with loc 24
# Didn't satisfy criteria [dist=12.9]; moving to distance: 145.8
# Didn't satisfy criteria [dist=145.8]; moving to distance: 182.9
# Didn't satisfy criteria [dist=182.9]; moving to distance: 219.3
# Finished with loc 25
# Didn't satisfy criteria [dist=70.6]; moving to distance: 78.9
# Didn't satisfy criteria [dist=78.9]; moving to distance: 87.7
# Didn't satisfy criteria [dist=87.7]; moving to distance: 88.5
# Didn't satisfy criteria [dist=88.5]; moving to distance: 93.5
# Didn't satisfy criteria [dist=93.5]; moving to distance: 119.8
# Didn't satisfy criteria [dist=119.8]; moving to distance: 120.1
# Didn't satisfy criteria [dist=120.1]; moving to distance: 122.0
# Didn't satisfy criteria [dist=122.0]; moving to distance: 123.9
# Didn't satisfy criteria [dist=123.9]; moving to distance: 124.4
# Didn't satisfy criteria [dist=124.4]; moving to distance: 171.5
# Didn't satisfy criteria [dist=171.5]; moving to distance: 197.3
# Finished with loc 26
# Didn't satisfy criteria [dist=44.4]; moving to distance: 52.8
# Didn't satisfy criteria [dist=52.8]; moving to distance: 54.4
# Didn't satisfy criteria [dist=54.4]; moving to distance: 60.7
# Didn't satisfy criteria [dist=60.7]; moving to distance: 68.3
# Didn't satisfy criteria [dist=68.3]; moving to distance: 86.6
# Didn't satisfy criteria [dist=86.6]; moving to distance: 87.8
# Didn't satisfy criteria [dist=87.8]; moving to distance: 89.0
# Didn't satisfy criteria [dist=89.0]; moving to distance: 91.9
# Didn't satisfy criteria [dist=91.9]; moving to distance: 100.7
# Didn't satisfy criteria [dist=100.7]; moving to distance: 103.8
# Didn't satisfy criteria [dist=103.8]; moving to distance: 145.6
# Didn't satisfy criteria [dist=145.6]; moving to distance: 147.0
# Didn't satisfy criteria [dist=147.0]; moving to distance: 147.4
# Didn't satisfy criteria [dist=147.4]; moving to distance: 237.1
# Finished with loc 27
# Didn't satisfy criteria [dist=93.5]; moving to distance: 108.5
# Didn't satisfy criteria [dist=108.5]; moving to distance: 110.1
# Didn't satisfy criteria [dist=110.1]; moving to distance: 187.2
# Didn't satisfy criteria [dist=187.2]; moving to distance: 191.5
# Didn't satisfy criteria [dist=191.5]; moving to distance: 215.8
# Finished with loc 28
# Didn't satisfy criteria [dist=42.0]; moving to distance: 43.3
# Didn't satisfy criteria [dist=43.3]; moving to distance: 72.2
# Didn't satisfy criteria [dist=72.2]; moving to distance: 81.3
# Didn't satisfy criteria [dist=81.3]; moving to distance: 119.4
# Didn't satisfy criteria [dist=119.4]; moving to distance: 126.7
# Didn't satisfy criteria [dist=126.7]; moving to distance: 209.4
# Finished with loc 29
# Didn't satisfy criteria [dist=9.0]; moving to distance: 12.2
# Didn't satisfy criteria [dist=12.2]; moving to distance: 16.1
# Found what we're after! [dist=16.1; station=785350-11630]
# Finished with loc 30
# Didn't satisfy criteria [dist=10.9]; moving to distance: 11.2
# Didn't satisfy criteria [dist=11.2]; moving to distance: 11.2
# Didn't satisfy criteria [dist=11.2]; moving to distance: 11.9
# Didn't satisfy criteria [dist=11.9]; moving to distance: 11.9
# Didn't satisfy criteria [dist=11.9]; moving to distance: 15.1
# Didn't satisfy criteria [dist=15.1]; moving to distance: 15.3
# Didn't satisfy criteria [dist=15.3]; moving to distance: 15.5
# Didn't satisfy criteria [dist=15.5]; moving to distance: 15.8
# Didn't satisfy criteria [dist=15.8]; moving to distance: 15.9
# Didn't satisfy criteria [dist=15.9]; moving to distance: 20.8
# Didn't satisfy criteria [dist=20.8]; moving to distance: 22.0
# Didn't satisfy criteria [dist=22.0]; moving to distance: 22.0
# Didn't satisfy criteria [dist=22.0]; moving to distance: 25.1
# Found what we're after! [dist=25.1; station=722080-13880]
# Finished with loc 31
# Didn't satisfy criteria [dist=97.7]; moving to distance: 172.3
# Didn't satisfy criteria [dist=172.3]; moving to distance: 176.1
# Didn't satisfy criteria [dist=176.1]; moving to distance: 185.5
# Didn't satisfy criteria [dist=185.5]; moving to distance: 222.6
# Finished with loc 32
# Didn't satisfy criteria [dist=87.7]; moving to distance: 89.6
# Didn't satisfy criteria [dist=89.6]; moving to distance: 94.0
# Didn't satisfy criteria [dist=94.0]; moving to distance: 102.5
# Didn't satisfy criteria [dist=102.5]; moving to distance: 102.9
# Didn't satisfy criteria [dist=102.9]; moving to distance: 112.8
# Didn't satisfy criteria [dist=112.8]; moving to distance: 116.3
# Didn't satisfy criteria [dist=116.3]; moving to distance: 127.7
# Didn't satisfy criteria [dist=127.7]; moving to distance: 139.4
# Didn't satisfy criteria [dist=139.4]; moving to distance: 149.7
# Didn't satisfy criteria [dist=149.7]; moving to distance: 183.1
# Didn't satisfy criteria [dist=183.1]; moving to distance: 185.1
# Didn't satisfy criteria [dist=185.1]; moving to distance: 185.2
# Didn't satisfy criteria [dist=185.2]; moving to distance: 185.2
# Didn't satisfy criteria [dist=185.2]; moving to distance: 186.0
# Didn't satisfy criteria [dist=186.0]; moving to distance: 193.2
# Didn't satisfy criteria [dist=193.2]; moving to distance: 193.4
# Didn't satisfy criteria [dist=193.4]; moving to distance: 193.6
# Didn't satisfy criteria [dist=193.6]; moving to distance: 209.1
# Finished with loc 33
# Didn't satisfy criteria [dist=32.6]; moving to distance: 77.9
# Didn't satisfy criteria [dist=77.9]; moving to distance: 91.5
# Didn't satisfy criteria [dist=91.5]; moving to distance: 92.1
# Didn't satisfy criteria [dist=92.1]; moving to distance: 96.3
# Didn't satisfy criteria [dist=96.3]; moving to distance: 99.3
# Didn't satisfy criteria [dist=99.3]; moving to distance: 99.6
# Didn't satisfy criteria [dist=99.6]; moving to distance: 118.9
# Didn't satisfy criteria [dist=118.9]; moving to distance: 119.5
# Didn't satisfy criteria [dist=119.5]; moving to distance: 128.0
# Didn't satisfy criteria [dist=128.0]; moving to distance: 138.3
# Didn't satisfy criteria [dist=138.3]; moving to distance: 151.2
# Didn't satisfy criteria [dist=151.2]; moving to distance: 153.0
# Didn't satisfy criteria [dist=153.0]; moving to distance: 178.3
# Didn't satisfy criteria [dist=178.3]; moving to distance: 186.0
# Didn't satisfy criteria [dist=186.0]; moving to distance: 187.5
# Didn't satisfy criteria [dist=187.5]; moving to distance: 208.9
# Finished with loc 34
# Didn't satisfy criteria [dist=34.3]; moving to distance: 43.0
# Didn't satisfy criteria [dist=43.0]; moving to distance: 52.4
# Didn't satisfy criteria [dist=52.4]; moving to distance: 52.4
# Didn't satisfy criteria [dist=52.4]; moving to distance: 60.5
# Didn't satisfy criteria [dist=60.5]; moving to distance: 60.9
# Didn't satisfy criteria [dist=60.9]; moving to distance: 70.0
# Didn't satisfy criteria [dist=70.0]; moving to distance: 71.0
# Didn't satisfy criteria [dist=71.0]; moving to distance: 72.1
# Didn't satisfy criteria [dist=72.1]; moving to distance: 93.3
# Didn't satisfy criteria [dist=93.3]; moving to distance: 112.1
# Didn't satisfy criteria [dist=112.1]; moving to distance: 117.9
# Didn't satisfy criteria [dist=117.9]; moving to distance: 121.3
# Didn't satisfy criteria [dist=121.3]; moving to distance: 123.5
# Didn't satisfy criteria [dist=123.5]; moving to distance: 123.5
# Didn't satisfy criteria [dist=123.5]; moving to distance: 132.5
# Didn't satisfy criteria [dist=132.5]; moving to distance: 136.0
# Didn't satisfy criteria [dist=136.0]; moving to distance: 136.0
# Didn't satisfy criteria [dist=136.0]; moving to distance: 143.4
# Didn't satisfy criteria [dist=143.4]; moving to distance: 148.8
# Didn't satisfy criteria [dist=148.8]; moving to distance: 150.9
# Didn't satisfy criteria [dist=150.9]; moving to distance: 166.1
# Didn't satisfy criteria [dist=166.1]; moving to distance: 169.3
# Didn't satisfy criteria [dist=169.3]; moving to distance: 170.7
# Didn't satisfy criteria [dist=170.7]; moving to distance: 187.6
# Didn't satisfy criteria [dist=187.6]; moving to distance: 195.2
# Didn't satisfy criteria [dist=195.2]; moving to distance: 218.0
# Finished with loc 35
# Didn't satisfy criteria [dist=47.4]; moving to distance: 49.7
# Found what we're after! [dist=49.7; station=478430-99999]
# Finished with loc 36
# Found what we're after! [dist=23.7; station=478170-99999]
# Finished with loc 37
# Didn't satisfy criteria [dist=4.6]; moving to distance: 27.1
# Didn't satisfy criteria [dist=27.1]; moving to distance: 31.5
# Found what we're after! [dist=31.5; station=477620-99999]
# Finished with loc 38
# Didn't satisfy criteria [dist=54.3]; moving to distance: 62.1
# Didn't satisfy criteria [dist=62.1]; moving to distance: 63.4
# Didn't satisfy criteria [dist=63.4]; moving to distance: 154.9
# Didn't satisfy criteria [dist=154.9]; moving to distance: 164.5
# Found what we're after! [dist=164.5; station=982230-99999]
# Finished with loc 39
# Didn't satisfy criteria [dist=22.5]; moving to distance: 27.2
# Didn't satisfy criteria [dist=27.2]; moving to distance: 27.3
# Didn't satisfy criteria [dist=27.3]; moving to distance: 28.9
# Didn't satisfy criteria [dist=28.9]; moving to distance: 53.2
# Didn't satisfy criteria [dist=53.2]; moving to distance: 62.8
# Didn't satisfy criteria [dist=62.8]; moving to distance: 80.5
# Didn't satisfy criteria [dist=80.5]; moving to distance: 86.6
# Didn't satisfy criteria [dist=86.6]; moving to distance: 87.1
# Didn't satisfy criteria [dist=87.1]; moving to distance: 88.0
# Didn't satisfy criteria [dist=88.0]; moving to distance: 88.2
# Didn't satisfy criteria [dist=88.2]; moving to distance: 104.5
# Didn't satisfy criteria [dist=104.5]; moving to distance: 108.5
# Didn't satisfy criteria [dist=108.5]; moving to distance: 121.6
# Didn't satisfy criteria [dist=121.6]; moving to distance: 126.2
# Didn't satisfy criteria [dist=126.2]; moving to distance: 130.2
# Didn't satisfy criteria [dist=130.2]; moving to distance: 149.8
# Didn't satisfy criteria [dist=149.8]; moving to distance: 223.0
# Finished with loc 40
# Didn't satisfy criteria [dist=8.6]; moving to distance: 8.6
# Didn't satisfy criteria [dist=8.6]; moving to distance: 21.2
# Didn't satisfy criteria [dist=21.2]; moving to distance: 21.4
# Didn't satisfy criteria [dist=21.4]; moving to distance: 22.0
# Didn't satisfy criteria [dist=22.0]; moving to distance: 22.4
# Didn't satisfy criteria [dist=22.4]; moving to distance: 29.7
# Didn't satisfy criteria [dist=29.7]; moving to distance: 31.7
# Didn't satisfy criteria [dist=31.7]; moving to distance: 32.1
# Found what we're after! [dist=32.1; station=722020-12839]
# Finished with loc 41
# Didn't satisfy criteria [dist=49.1]; moving to distance: 49.1
# Didn't satisfy criteria [dist=49.1]; moving to distance: 58.2
# Didn't satisfy criteria [dist=58.2]; moving to distance: 59.4
# Didn't satisfy criteria [dist=59.4]; moving to distance: 68.4
# Didn't satisfy criteria [dist=68.4]; moving to distance: 71.8
# Found what we're after! [dist=71.8; station=911650-22536]
# Finished with loc 42
# Didn't satisfy criteria [dist=84.8]; moving to distance: 121.6
# Found what we're after! [dist=121.6; station=982330-99999]
# Finished with loc 43
# Found what we're after! [dist=73.8; station=982330-99999]
# Finished with loc 44
# Didn't satisfy criteria [dist=36.2]; moving to distance: 40.9
# Didn't satisfy criteria [dist=40.9]; moving to distance: 66.8
# Found what we're after! [dist=66.8; station=478360-99999]
# Finished with loc 45
# Found what we're after! [dist=9.8; station=478290-99999]
# Finished with loc 46
# Didn't satisfy criteria [dist=89.4]; moving to distance: 125.0
# Didn't satisfy criteria [dist=125.0]; moving to distance: 200.3
# Finished with loc 47
# Didn't satisfy criteria [dist=29.0]; moving to distance: 123.7
# Didn't satisfy criteria [dist=123.7]; moving to distance: 127.8
# Didn't satisfy criteria [dist=127.8]; moving to distance: 176.8
# Didn't satisfy criteria [dist=176.8]; moving to distance: 194.5
# Didn't satisfy criteria [dist=194.5]; moving to distance: 209.1
# Finished with loc 48
# Didn't satisfy criteria [dist=34.4]; moving to distance: 36.8
# Didn't satisfy criteria [dist=36.8]; moving to distance: 63.7
# Didn't satisfy criteria [dist=63.7]; moving to distance: 89.0
# Didn't satisfy criteria [dist=89.0]; moving to distance: 103.2
# Didn't satisfy criteria [dist=103.2]; moving to distance: 130.9
# Didn't satisfy criteria [dist=130.9]; moving to distance: 179.1
# Didn't satisfy criteria [dist=179.1]; moving to distance: 190.1
# Didn't satisfy criteria [dist=190.1]; moving to distance: 190.1
# Didn't satisfy criteria [dist=190.1]; moving to distance: 208.4
# Finished with loc 49
# Didn't satisfy criteria [dist=26.4]; moving to distance: 54.0
# Didn't satisfy criteria [dist=54.0]; moving to distance: 65.2
# Didn't satisfy criteria [dist=65.2]; moving to distance: 65.3
# Didn't satisfy criteria [dist=65.3]; moving to distance: 69.8
# Didn't satisfy criteria [dist=69.8]; moving to distance: 69.8
# Didn't satisfy criteria [dist=69.8]; moving to distance: 71.0
# Found what we're after! [dist=71.0; station=467660-99999]
# Finished with loc 50
# Found what we're after! [dist=34.7; station=467060-99999]
# Finished with loc 51
# Didn't satisfy criteria [dist=46.2]; moving to distance: 132.1
# Didn't satisfy criteria [dist=132.1]; moving to distance: 147.7
# Didn't satisfy criteria [dist=147.7]; moving to distance: 173.6
# Didn't satisfy criteria [dist=173.6]; moving to distance: 221.1
# Finished with loc 52
# Didn't satisfy criteria [dist=35.2]; moving to distance: 154.0
# Didn't satisfy criteria [dist=154.0]; moving to distance: 162.4
# Didn't satisfy criteria [dist=162.4]; moving to distance: 200.8
# Finished with loc 53
# Found what we're after! [dist=29.1; station=943050-99999]
# Finished with loc 54
# Didn't satisfy criteria [dist=14.6]; moving to distance: 16.0
# Didn't satisfy criteria [dist=16.0]; moving to distance: 21.5
# Didn't satisfy criteria [dist=21.5]; moving to distance: 21.6
# Didn't satisfy criteria [dist=21.6]; moving to distance: 21.9
# Didn't satisfy criteria [dist=21.9]; moving to distance: 26.7
# Didn't satisfy criteria [dist=26.7]; moving to distance: 26.7
# Didn't satisfy criteria [dist=26.7]; moving to distance: 39.7
# Didn't satisfy criteria [dist=39.7]; moving to distance: 42.1
# Didn't satisfy criteria [dist=42.1]; moving to distance: 42.1
# Found what we're after! [dist=42.1; station=747770-03852]
# Finished with loc 55
# Didn't satisfy criteria [dist=21.1]; moving to distance: 24.3
# Didn't satisfy criteria [dist=24.3]; moving to distance: 61.0
# Didn't satisfy criteria [dist=61.0]; moving to distance: 61.1
# Didn't satisfy criteria [dist=61.1]; moving to distance: 110.4
# Didn't satisfy criteria [dist=110.4]; moving to distance: 111.1
# Didn't satisfy criteria [dist=111.1]; moving to distance: 124.2
# Found what we're after! [dist=124.2; station=984440-99999]
# Finished with loc 56
# Didn't satisfy criteria [dist=24.6]; moving to distance: 37.4
# Didn't satisfy criteria [dist=37.4]; moving to distance: 59.7
# Didn't satisfy criteria [dist=59.7]; moving to distance: 63.9
# Didn't satisfy criteria [dist=63.9]; moving to distance: 72.2
# Didn't satisfy criteria [dist=72.2]; moving to distance: 84.9
# Didn't satisfy criteria [dist=84.9]; moving to distance: 88.3
# Didn't satisfy criteria [dist=88.3]; moving to distance: 94.0
# Found what we're after! [dist=94.0; station=984290-99999]
# Finished with loc 57
# Didn't satisfy criteria [dist=60.0]; moving to distance: 99.5
# Didn't satisfy criteria [dist=99.5]; moving to distance: 172.2
# Didn't satisfy criteria [dist=172.2]; moving to distance: 184.9
# Didn't satisfy criteria [dist=184.9]; moving to distance: 232.7
# Finished with loc 58
# Didn't satisfy criteria [dist=33.9]; moving to distance: 125.9
# Didn't satisfy criteria [dist=125.9]; moving to distance: 146.7
# Didn't satisfy criteria [dist=146.7]; moving to distance: 184.1
# Didn't satisfy criteria [dist=184.1]; moving to distance: 220.3
# Finished with loc 59
# Didn't satisfy criteria [dist=18.3]; moving to distance: 72.5
# Didn't satisfy criteria [dist=72.5]; moving to distance: 118.5
# Found what we're after! [dist=118.5; station=943120-99999]
# Finished with loc 60
# Didn't satisfy criteria [dist=25.4]; moving to distance: 93.6
# Didn't satisfy criteria [dist=93.6]; moving to distance: 94.2
# Found what we're after! [dist=94.2; station=943120-99999]
# Finished with loc 61
# Didn't satisfy criteria [dist=59.9]; moving to distance: 70.6
# Didn't satisfy criteria [dist=70.6]; moving to distance: 94.2
# Found what we're after! [dist=94.2; station=943120-99999]
# Finished with loc 62
# Didn't satisfy criteria [dist=24.0]; moving to distance: 40.9
# Didn't satisfy criteria [dist=40.9]; moving to distance: 93.4
# Didn't satisfy criteria [dist=93.4]; moving to distance: 98.7
# Didn't satisfy criteria [dist=98.7]; moving to distance: 148.3
# Didn't satisfy criteria [dist=148.3]; moving to distance: 185.0
# Didn't satisfy criteria [dist=185.0]; moving to distance: 192.3
# Didn't satisfy criteria [dist=192.3]; moving to distance: 218.5
# Finished with loc 63
# Didn't satisfy criteria [dist=44.5]; moving to distance: 78.5
# Didn't satisfy criteria [dist=78.5]; moving to distance: 80.0
# Didn't satisfy criteria [dist=80.0]; moving to distance: 118.7
# Didn't satisfy criteria [dist=118.7]; moving to distance: 135.7
# Didn't satisfy criteria [dist=135.7]; moving to distance: 161.5
# Didn't satisfy criteria [dist=161.5]; moving to distance: 187.1
# Didn't satisfy criteria [dist=187.1]; moving to distance: 194.9
# Didn't satisfy criteria [dist=194.9]; moving to distance: 220.0
# Finished with loc 64
# Didn't satisfy criteria [dist=10.4]; moving to distance: 36.3
# Didn't satisfy criteria [dist=36.3]; moving to distance: 41.4
# Didn't satisfy criteria [dist=41.4]; moving to distance: 78.9
# Found what we're after! [dist=78.9; station=943060-99999]
# Finished with loc 65
# Found what we're after! [dist=26.5; station=943060-99999]
# Finished with loc 66
# Didn't satisfy criteria [dist=77.1]; moving to distance: 122.6
# Didn't satisfy criteria [dist=122.6]; moving to distance: 139.4
# Found what we're after! [dist=139.4; station=943060-99999]
# Finished with loc 67
# Didn't satisfy criteria [dist=58.9]; moving to distance: 59.2
# Didn't satisfy criteria [dist=59.2]; moving to distance: 61.8
# Found what we're after! [dist=61.8; station=479120-99999]
# Finished with loc 68
# Didn't satisfy criteria [dist=10.2]; moving to distance: 29.0
# Didn't satisfy criteria [dist=29.0]; moving to distance: 35.4
# Didn't satisfy criteria [dist=35.4]; moving to distance: 39.3
# Didn't satisfy criteria [dist=39.3]; moving to distance: 55.9
# Didn't satisfy criteria [dist=55.9]; moving to distance: 67.0
# Didn't satisfy criteria [dist=67.0]; moving to distance: 68.5
# Didn't satisfy criteria [dist=68.5]; moving to distance: 74.2
# Didn't satisfy criteria [dist=74.2]; moving to distance: 84.3
# Didn't satisfy criteria [dist=84.3]; moving to distance: 86.2
# Found what we're after! [dist=86.2; station=428090-99999]
# Finished with loc 69
# Didn't satisfy criteria [dist=76.3]; moving to distance: 82.5
# Didn't satisfy criteria [dist=82.5]; moving to distance: 84.0
# Didn't satisfy criteria [dist=84.0]; moving to distance: 165.2
# Didn't satisfy criteria [dist=165.2]; moving to distance: 190.5
# Didn't satisfy criteria [dist=190.5]; moving to distance: 196.8
# Didn't satisfy criteria [dist=196.8]; moving to distance: 215.2
# Finished with loc 70
# Didn't satisfy criteria [dist=103.2]; moving to distance: 127.3
# Didn't satisfy criteria [dist=127.3]; moving to distance: 181.6
# Didn't satisfy criteria [dist=181.6]; moving to distance: 191.2
# Didn't satisfy criteria [dist=191.2]; moving to distance: 192.3
# Didn't satisfy criteria [dist=192.3]; moving to distance: 192.6
# Didn't satisfy criteria [dist=192.6]; moving to distance: 235.0
# Finished with loc 71
# Didn't satisfy criteria [dist=24.8]; moving to distance: 106.3
# Didn't satisfy criteria [dist=106.3]; moving to distance: 106.6
# Didn't satisfy criteria [dist=106.6]; moving to distance: 133.7
# Didn't satisfy criteria [dist=133.7]; moving to distance: 154.0
# Didn't satisfy criteria [dist=154.0]; moving to distance: 158.4
# Didn't satisfy criteria [dist=158.4]; moving to distance: 171.6
# Didn't satisfy criteria [dist=171.6]; moving to distance: 177.7
# Didn't satisfy criteria [dist=177.7]; moving to distance: 187.3
# Didn't satisfy criteria [dist=187.3]; moving to distance: 191.4
# Didn't satisfy criteria [dist=191.4]; moving to distance: 208.0
# Finished with loc 72
# Didn't satisfy criteria [dist=40.8]; moving to distance: 64.6
# Didn't satisfy criteria [dist=64.6]; moving to distance: 65.2
# Didn't satisfy criteria [dist=65.2]; moving to distance: 99.9
# Didn't satisfy criteria [dist=99.9]; moving to distance: 114.7
# Didn't satisfy criteria [dist=114.7]; moving to distance: 160.7
# Didn't satisfy criteria [dist=160.7]; moving to distance: 181.5
# Didn't satisfy criteria [dist=181.5]; moving to distance: 186.6
# Didn't satisfy criteria [dist=186.6]; moving to distance: 190.2
# Didn't satisfy criteria [dist=190.2]; moving to distance: 223.8
# Finished with loc 73
# Didn't satisfy criteria [dist=53.4]; moving to distance: 54.9
# Didn't satisfy criteria [dist=54.9]; moving to distance: 77.3
# Didn't satisfy criteria [dist=77.3]; moving to distance: 86.5
# Didn't satisfy criteria [dist=86.5]; moving to distance: 118.7
# Didn't satisfy criteria [dist=118.7]; moving to distance: 139.0
# Didn't satisfy criteria [dist=139.0]; moving to distance: 225.8
# Finished with loc 74
# Didn't satisfy criteria [dist=7.5]; moving to distance: 13.3
# Didn't satisfy criteria [dist=13.3]; moving to distance: 81.3
# Found what we're after! [dist=81.3; station=984440-99999]
# Finished with loc 75
# Didn't satisfy criteria [dist=29.6]; moving to distance: 30.0
# Found what we're after! [dist=30.0; station=943020-99999]
# Finished with loc 76
# Didn't satisfy criteria [dist=59.0]; moving to distance: 59.2
# Found what we're after! [dist=59.2; station=943020-99999]
# Finished with loc 77
# Didn't satisfy criteria [dist=71.1]; moving to distance: 116.5
# Found what we're after! [dist=116.5; station=943020-99999]
# Finished with loc 78
# Didn't satisfy criteria [dist=77.9]; moving to distance: 146.6
# Found what we're after! [dist=146.6; station=943020-99999]
# Finished with loc 79
# Didn't satisfy criteria [dist=99.1]; moving to distance: 150.1
# Found what we're after! [dist=150.1; station=943000-99999]
# Finished with loc 80
# Didn't satisfy criteria [dist=113.3]; moving to distance: 125.9
# Didn't satisfy criteria [dist=125.9]; moving to distance: 136.9
# Found what we're after! [dist=136.9; station=943000-99999]
# Finished with loc 81
# Found what we're after! [dist=9.3; station=478380-99999]
# Finished with loc 82
# Didn't satisfy criteria [dist=50.6]; moving to distance: 81.4
# Didn't satisfy criteria [dist=81.4]; moving to distance: 91.8
# Didn't satisfy criteria [dist=91.8]; moving to distance: 96.9
# Didn't satisfy criteria [dist=96.9]; moving to distance: 104.5
# Didn't satisfy criteria [dist=104.5]; moving to distance: 188.5
# Didn't satisfy criteria [dist=188.5]; moving to distance: 190.1
# Didn't satisfy criteria [dist=190.1]; moving to distance: 190.8
# Didn't satisfy criteria [dist=190.8]; moving to distance: 205.5
# Finished with loc 83
# Didn't satisfy criteria [dist=33.1]; moving to distance: 34.7
# Didn't satisfy criteria [dist=34.7]; moving to distance: 55.9
# Didn't satisfy criteria [dist=55.9]; moving to distance: 61.0
# Didn't satisfy criteria [dist=61.0]; moving to distance: 84.9
# Didn't satisfy criteria [dist=84.9]; moving to distance: 127.2
# Didn't satisfy criteria [dist=127.2]; moving to distance: 162.9
# Didn't satisfy criteria [dist=162.9]; moving to distance: 165.8
# Didn't satisfy criteria [dist=165.8]; moving to distance: 172.0
# Didn't satisfy criteria [dist=172.0]; moving to distance: 198.0
# Finished with loc 84
# Didn't satisfy criteria [dist=38.3]; moving to distance: 39.9
# Didn't satisfy criteria [dist=39.9]; moving to distance: 71.3
# Didn't satisfy criteria [dist=71.3]; moving to distance: 75.7
# Didn't satisfy criteria [dist=75.7]; moving to distance: 76.5
# Didn't satisfy criteria [dist=76.5]; moving to distance: 77.5
# Didn't satisfy criteria [dist=77.5]; moving to distance: 121.8
# Found what we're after! [dist=121.8; station=943120-99999]
# Finished with loc 85
# Didn't satisfy criteria [dist=43.2]; moving to distance: 130.8
# Didn't satisfy criteria [dist=130.8]; moving to distance: 137.4
# Didn't satisfy criteria [dist=137.4]; moving to distance: 151.8
# Didn't satisfy criteria [dist=151.8]; moving to distance: 152.1
# Didn't satisfy criteria [dist=152.1]; moving to distance: 152.7
# Didn't satisfy criteria [dist=152.7]; moving to distance: 182.6
# Didn't satisfy criteria [dist=182.6]; moving to distance: 187.5
# Didn't satisfy criteria [dist=187.5]; moving to distance: 215.3
# Finished with loc 86
# Didn't satisfy criteria [dist=89.7]; moving to distance: 161.9
# Didn't satisfy criteria [dist=161.9]; moving to distance: 227.9
# Finished with loc 87
# Didn't satisfy criteria [dist=15.1]; moving to distance: 90.8
# Didn't satisfy criteria [dist=90.8]; moving to distance: 99.6
# Didn't satisfy criteria [dist=99.6]; moving to distance: 192.5
# Didn't satisfy criteria [dist=192.5]; moving to distance: 237.4
# Finished with loc 88
# Found what we're after! [dist=41.7; station=942030-99999]
# Finished with loc 89
# Found what we're after! [dist=66.9; station=942030-99999]
# Finished with loc 90
# Didn't satisfy criteria [dist=54.0]; moving to distance: 65.9
# Didn't satisfy criteria [dist=65.9]; moving to distance: 65.9
# Didn't satisfy criteria [dist=65.9]; moving to distance: 67.3
# Didn't satisfy criteria [dist=67.3]; moving to distance: 88.8
# Didn't satisfy criteria [dist=88.8]; moving to distance: 90.1
# Didn't satisfy criteria [dist=90.1]; moving to distance: 90.1
# Didn't satisfy criteria [dist=90.1]; moving to distance: 90.6
# Didn't satisfy criteria [dist=90.6]; moving to distance: 93.5
# Didn't satisfy criteria [dist=93.5]; moving to distance: 95.0
# Didn't satisfy criteria [dist=95.0]; moving to distance: 111.5
# Didn't satisfy criteria [dist=111.5]; moving to distance: 136.9
# Found what we're after! [dist=136.9; station=595590-99999]
# Finished with loc 91
# Didn't satisfy criteria [dist=15.5]; moving to distance: 31.4
# Didn't satisfy criteria [dist=31.4]; moving to distance: 31.9
# Didn't satisfy criteria [dist=31.9]; moving to distance: 37.2
# Didn't satisfy criteria [dist=37.2]; moving to distance: 37.2
# Didn't satisfy criteria [dist=37.2]; moving to distance: 37.9
# Didn't satisfy criteria [dist=37.9]; moving to distance: 52.6
# Didn't satisfy criteria [dist=52.6]; moving to distance: 52.8
# Didn't satisfy criteria [dist=52.8]; moving to distance: 64.9
# Didn't satisfy criteria [dist=64.9]; moving to distance: 64.9
# Didn't satisfy criteria [dist=64.9]; moving to distance: 86.4
# Didn't satisfy criteria [dist=86.4]; moving to distance: 87.4
# Didn't satisfy criteria [dist=87.4]; moving to distance: 89.7
# Didn't satisfy criteria [dist=89.7]; moving to distance: 91.5
# Didn't satisfy criteria [dist=91.5]; moving to distance: 94.6
# Didn't satisfy criteria [dist=94.6]; moving to distance: 95.7
# Didn't satisfy criteria [dist=95.7]; moving to distance: 97.2
# Didn't satisfy criteria [dist=97.2]; moving to distance: 100.6
# Didn't satisfy criteria [dist=100.6]; moving to distance: 102.9
# Found what we're after! [dist=102.9; station=593580-99999]
# Finished with loc 92
# Didn't satisfy criteria [dist=31.5]; moving to distance: 121.4
# Didn't satisfy criteria [dist=121.4]; moving to distance: 125.3
# Found what we're after! [dist=125.3; station=942030-99999]
# Finished with loc 93
# Didn't satisfy criteria [dist=48.8]; moving to distance: 110.1
# Didn't satisfy criteria [dist=110.1]; moving to distance: 142.6
# Found what we're after! [dist=142.6; station=942030-99999]
# Finished with loc 94
# Didn't satisfy criteria [dist=56.8]; moving to distance: 83.2
# Didn't satisfy criteria [dist=83.2]; moving to distance: 106.7
# Found what we're after! [dist=106.7; station=943100-99999]
# Finished with loc 95
# Didn't satisfy criteria [dist=38.9]; moving to distance: 109.1
# Didn't satisfy criteria [dist=109.1]; moving to distance: 110.4
# Didn't satisfy criteria [dist=110.4]; moving to distance: 111.8
# Found what we're after! [dist=111.8; station=943100-99999]
# Finished with loc 96
# Didn't satisfy criteria [dist=52.3]; moving to distance: 71.7
# Didn't satisfy criteria [dist=71.7]; moving to distance: 119.7
# Found what we're after! [dist=119.7; station=943120-99999]
# Finished with loc 97
# Didn't satisfy criteria [dist=48.6]; moving to distance: 126.0
# Didn't satisfy criteria [dist=126.0]; moving to distance: 129.6
# Didn't satisfy criteria [dist=129.6]; moving to distance: 202.2
# Finished with loc 98
# Didn't satisfy criteria [dist=84.6]; moving to distance: 107.8
# Didn't satisfy criteria [dist=107.8]; moving to distance: 108.8
# Didn't satisfy criteria [dist=108.8]; moving to distance: 116.7
# Didn't satisfy criteria [dist=116.7]; moving to distance: 118.9
# Didn't satisfy criteria [dist=118.9]; moving to distance: 125.3
# Didn't satisfy criteria [dist=125.3]; moving to distance: 218.9
# Finished with loc 99
# Didn't satisfy criteria [dist=36.3]; moving to distance: 54.9
# Didn't satisfy criteria [dist=54.9]; moving to distance: 55.9
# Didn't satisfy criteria [dist=55.9]; moving to distance: 115.2
# Didn't satisfy criteria [dist=115.2]; moving to distance: 126.9
# Didn't satisfy criteria [dist=126.9]; moving to distance: 133.4
# Didn't satisfy criteria [dist=133.4]; moving to distance: 205.7
# Finished with loc 100
# Didn't satisfy criteria [dist=61.8]; moving to distance: 71.8
# Didn't satisfy criteria [dist=71.8]; moving to distance: 105.5
# Didn't satisfy criteria [dist=105.5]; moving to distance: 107.3
# Didn't satisfy criteria [dist=107.3]; moving to distance: 168.2
# Didn't satisfy criteria [dist=168.2]; moving to distance: 222.7
# Finished with loc 101
# Found what we're after! [dist=9.6; station=915900-99999]
# Finished with loc 102
# Didn't satisfy criteria [dist=83.2]; moving to distance: 101.9
# Found what we're after! [dist=101.9; station=471680-99999]
# Finished with loc 103
# Didn't satisfy criteria [dist=7.5]; moving to distance: 112.9
# Found what we're after! [dist=112.9; station=915540-99999]
# Finished with loc 104
# Didn't satisfy criteria [dist=19.7]; moving to distance: 90.9
# Didn't satisfy criteria [dist=90.9]; moving to distance: 103.7
# Didn't satisfy criteria [dist=103.7]; moving to distance: 192.1
# Didn't satisfy criteria [dist=192.1]; moving to distance: 240.8
# Finished with loc 105
# Didn't satisfy criteria [dist=59.2]; moving to distance: 84.1
# Didn't satisfy criteria [dist=84.1]; moving to distance: 102.5
# Didn't satisfy criteria [dist=102.5]; moving to distance: 157.1
# Found what we're after! [dist=157.1; station=953170-99999]
# Finished with loc 106
# Didn't satisfy criteria [dist=48.6]; moving to distance: 95.7
# Didn't satisfy criteria [dist=95.7]; moving to distance: 117.0
# Didn't satisfy criteria [dist=117.0]; moving to distance: 119.9
# Found what we're after! [dist=119.9; station=953170-99999]
# Finished with loc 107
# Didn't satisfy criteria [dist=43.2]; moving to distance: 50.0
# Found what we're after! [dist=50.0; station=984460-99999]
# Finished with loc 108
# Didn't satisfy criteria [dist=30.0]; moving to distance: 33.3
# Didn't satisfy criteria [dist=33.3]; moving to distance: 33.8
# Found what we're after! [dist=33.8; station=722106-12835]
# Finished with loc 109
# Found what we're after! [dist=37.9; station=478170-99999]
# Finished with loc 110
# Didn't satisfy criteria [dist=6.3]; moving to distance: 20.7
# Found what we're after! [dist=20.7; station=478090-99999]
# Finished with loc 111
# Didn't satisfy criteria [dist=114.4]; moving to distance: 115.6
# Didn't satisfy criteria [dist=115.6]; moving to distance: 121.3
# Didn't satisfy criteria [dist=121.3]; moving to distance: 132.0
# Didn't satisfy criteria [dist=132.0]; moving to distance: 218.1
# Finished with loc 112
# Didn't satisfy criteria [dist=25.4]; moving to distance: 45.3
# Didn't satisfy criteria [dist=45.3]; moving to distance: 45.6
# Didn't satisfy criteria [dist=45.6]; moving to distance: 45.6
# Didn't satisfy criteria [dist=45.6]; moving to distance: 49.8
# Didn't satisfy criteria [dist=49.8]; moving to distance: 60.9
# Didn't satisfy criteria [dist=60.9]; moving to distance: 68.2
# Didn't satisfy criteria [dist=68.2]; moving to distance: 79.8
# Didn't satisfy criteria [dist=79.8]; moving to distance: 82.1
# Didn't satisfy criteria [dist=82.1]; moving to distance: 83.4
# Didn't satisfy criteria [dist=83.4]; moving to distance: 87.0
# Didn't satisfy criteria [dist=87.0]; moving to distance: 98.4
# Didn't satisfy criteria [dist=98.4]; moving to distance: 99.8
# Didn't satisfy criteria [dist=99.8]; moving to distance: 105.4
# Didn't satisfy criteria [dist=105.4]; moving to distance: 105.8
# Didn't satisfy criteria [dist=105.8]; moving to distance: 106.7
# Didn't satisfy criteria [dist=106.7]; moving to distance: 107.4
# Didn't satisfy criteria [dist=107.4]; moving to distance: 119.0
# Didn't satisfy criteria [dist=119.0]; moving to distance: 128.5
# Didn't satisfy criteria [dist=128.5]; moving to distance: 131.7
# Didn't satisfy criteria [dist=131.7]; moving to distance: 143.6
# Didn't satisfy criteria [dist=143.6]; moving to distance: 146.3
# Didn't satisfy criteria [dist=146.3]; moving to distance: 147.3
# Didn't satisfy criteria [dist=147.3]; moving to distance: 175.2
# Didn't satisfy criteria [dist=175.2]; moving to distance: 177.7
# Didn't satisfy criteria [dist=177.7]; moving to distance: 179.4
# Didn't satisfy criteria [dist=179.4]; moving to distance: 185.8
# Didn't satisfy criteria [dist=185.8]; moving to distance: 186.8
# Didn't satisfy criteria [dist=186.8]; moving to distance: 190.8
# Didn't satisfy criteria [dist=190.8]; moving to distance: 191.6
# Didn't satisfy criteria [dist=191.6]; moving to distance: 194.1
# Didn't satisfy criteria [dist=194.1]; moving to distance: 203.3
# Finished with loc 113
# Didn't satisfy criteria [dist=107.8]; moving to distance: 107.9
# Didn't satisfy criteria [dist=107.9]; moving to distance: 108.2
# Didn't satisfy criteria [dist=108.2]; moving to distance: 125.3
# Found what we're after! [dist=125.3; station=722500-12919]
# Finished with loc 114
# Didn't satisfy criteria [dist=17.4]; moving to distance: 19.0
# Didn't satisfy criteria [dist=19.0]; moving to distance: 19.0
# Didn't satisfy criteria [dist=19.0]; moving to distance: 19.7
# Didn't satisfy criteria [dist=19.7]; moving to distance: 20.9
# Didn't satisfy criteria [dist=20.9]; moving to distance: 20.9
# Didn't satisfy criteria [dist=20.9]; moving to distance: 23.0
# Didn't satisfy criteria [dist=23.0]; moving to distance: 34.1
# Didn't satisfy criteria [dist=34.1]; moving to distance: 34.1
# Didn't satisfy criteria [dist=34.1]; moving to distance: 35.1
# Didn't satisfy criteria [dist=35.1]; moving to distance: 35.9
# Didn't satisfy criteria [dist=35.9]; moving to distance: 36.0
# Didn't satisfy criteria [dist=36.0]; moving to distance: 36.1
# Didn't satisfy criteria [dist=36.1]; moving to distance: 43.7
# Didn't satisfy criteria [dist=43.7]; moving to distance: 45.4
# Didn't satisfy criteria [dist=45.4]; moving to distance: 46.6
# Didn't satisfy criteria [dist=46.6]; moving to distance: 47.5
# Didn't satisfy criteria [dist=47.5]; moving to distance: 61.7
# Didn't satisfy criteria [dist=61.7]; moving to distance: 61.8
# Didn't satisfy criteria [dist=61.8]; moving to distance: 61.8
# Didn't satisfy criteria [dist=61.8]; moving to distance: 61.9
# Didn't satisfy criteria [dist=61.9]; moving to distance: 62.4
# Didn't satisfy criteria [dist=62.4]; moving to distance: 63.5
# Didn't satisfy criteria [dist=63.5]; moving to distance: 66.1
# Didn't satisfy criteria [dist=66.1]; moving to distance: 66.8
# Didn't satisfy criteria [dist=66.8]; moving to distance: 68.8
# Didn't satisfy criteria [dist=68.8]; moving to distance: 70.3
# Didn't satisfy criteria [dist=70.3]; moving to distance: 72.5
# Didn't satisfy criteria [dist=72.5]; moving to distance: 73.6
# Didn't satisfy criteria [dist=73.6]; moving to distance: 74.9
# Didn't satisfy criteria [dist=74.9]; moving to distance: 75.5
# Didn't satisfy criteria [dist=75.5]; moving to distance: 78.8
# Didn't satisfy criteria [dist=78.8]; moving to distance: 81.0
# Didn't satisfy criteria [dist=81.0]; moving to distance: 85.7
# Didn't satisfy criteria [dist=85.7]; moving to distance: 86.1
# Didn't satisfy criteria [dist=86.1]; moving to distance: 86.4
# Didn't satisfy criteria [dist=86.4]; moving to distance: 91.0
# Didn't satisfy criteria [dist=91.0]; moving to distance: 93.1
# Didn't satisfy criteria [dist=93.1]; moving to distance: 94.2
# Didn't satisfy criteria [dist=94.2]; moving to distance: 94.6
# Didn't satisfy criteria [dist=94.6]; moving to distance: 95.1
# Didn't satisfy criteria [dist=95.1]; moving to distance: 96.3
# Didn't satisfy criteria [dist=96.3]; moving to distance: 97.7
# Didn't satisfy criteria [dist=97.7]; moving to distance: 98.1
# Didn't satisfy criteria [dist=98.1]; moving to distance: 101.6
# Didn't satisfy criteria [dist=101.6]; moving to distance: 102.5
# Didn't satisfy criteria [dist=102.5]; moving to distance: 103.1
# Didn't satisfy criteria [dist=103.1]; moving to distance: 104.6
# Didn't satisfy criteria [dist=104.6]; moving to distance: 106.9
# Didn't satisfy criteria [dist=106.9]; moving to distance: 106.9
# Didn't satisfy criteria [dist=106.9]; moving to distance: 107.0
# Didn't satisfy criteria [dist=107.0]; moving to distance: 111.7
# Didn't satisfy criteria [dist=111.7]; moving to distance: 111.9
# Didn't satisfy criteria [dist=111.9]; moving to distance: 112.7
# Didn't satisfy criteria [dist=112.7]; moving to distance: 112.7
# Didn't satisfy criteria [dist=112.7]; moving to distance: 116.5
# Didn't satisfy criteria [dist=116.5]; moving to distance: 116.9
# Didn't satisfy criteria [dist=116.9]; moving to distance: 117.9
# ...
# Didn't satisfy criteria [dist=107.4]; moving to distance: 134.1
# Didn't satisfy criteria [dist=134.1]; moving to distance: 147.4
# Didn't satisfy criteria [dist=147.4]; moving to distance: 174.9
# Didn't satisfy criteria [dist=174.9]; moving to distance: 178.2
# Didn't satisfy criteria [dist=178.2]; moving to distance: 193.4
# Didn't satisfy criteria [dist=193.4]; moving to distance: 211.9
# Finished with loc 154
# Didn't satisfy criteria [dist=23.2]; moving to distance: 35.7
# Didn't satisfy criteria [dist=35.7]; moving to distance: 36.5
# Didn't satisfy criteria [dist=36.5]; moving to distance: 85.2
# Didn't satisfy criteria [dist=85.2]; moving to distance: 91.4
# Didn't satisfy criteria [dist=91.4]; moving to distance: 99.8
# Didn't satisfy criteria [dist=99.8]; moving to distance: 102.6
# Didn't satisfy criteria [dist=102.6]; moving to distance: 105.7
# Didn't satisfy criteria [dist=105.7]; moving to distance: 106.5
# Didn't satisfy criteria [dist=106.5]; moving to distance: 118.1
# Didn't satisfy criteria [dist=118.1]; moving to distance: 119.0
# Didn't satisfy criteria [dist=119.0]; moving to distance: 119.8
# Didn't satisfy criteria [dist=119.8]; moving to distance: 120.3
# Didn't satisfy criteria [dist=120.3]; moving to distance: 158.5
# Didn't satisfy criteria [dist=158.5]; moving to distance: 165.1
# Didn't satisfy criteria [dist=165.1]; moving to distance: 182.1
# Didn't satisfy criteria [dist=182.1]; moving to distance: 194.9
# Didn't satisfy criteria [dist=194.9]; moving to distance: 205.7
# Finished with loc 155
# Found what we're after! [dist=31.2; station=985380-99999]
# Finished with loc 156
# Didn't satisfy criteria [dist=27.3]; moving to distance: 27.3
# Didn't satisfy criteria [dist=27.3]; moving to distance: 44.7
# Found what we're after! [dist=44.7; station=984440-99999]
# Finished with loc 157
# Didn't satisfy criteria [dist=18.2]; moving to distance: 38.5
# Found what we're after! [dist=38.5; station=984270-99999]
# Finished with loc 158
# Didn't satisfy criteria [dist=12.2]; moving to distance: 36.3
# Found what we're after! [dist=36.3; station=597580-99999]
# Finished with loc 159
# Didn't satisfy criteria [dist=6.7]; moving to distance: 33.5
# Didn't satisfy criteria [dist=33.5]; moving to distance: 33.6
# Didn't satisfy criteria [dist=33.6]; moving to distance: 138.8
# Didn't satisfy criteria [dist=138.8]; moving to distance: 139.0
# Didn't satisfy criteria [dist=139.0]; moving to distance: 146.8
# Didn't satisfy criteria [dist=146.8]; moving to distance: 174.5
# Didn't satisfy criteria [dist=174.5]; moving to distance: 292.8
# Finished with loc 160
# Didn't satisfy criteria [dist=42.1]; moving to distance: 42.5
# Didn't satisfy criteria [dist=42.5]; moving to distance: 42.6
# Didn't satisfy criteria [dist=42.6]; moving to distance: 90.1
# Didn't satisfy criteria [dist=90.1]; moving to distance: 90.1
# Didn't satisfy criteria [dist=90.1]; moving to distance: 98.6
# Didn't satisfy criteria [dist=98.6]; moving to distance: 173.8
# Didn't satisfy criteria [dist=173.8]; moving to distance: 245.1
# Finished with loc 161
# Found what we're after! [dist=29.3; station=985530-99999]
# Finished with loc 162
# Found what we're after! [dist=27.0; station=941400-99999]
# Finished with loc 163
# Found what we're after! [dist=43.0; station=953700-99999]
# Finished with loc 164
# Didn't satisfy criteria [dist=18.6]; moving to distance: 45.5
# Found what we're after! [dist=45.5; station=953700-99999]
# Finished with loc 165
# Didn't satisfy criteria [dist=45.4]; moving to distance: 45.8
# Didn't satisfy criteria [dist=45.8]; moving to distance: 46.7
# Didn't satisfy criteria [dist=46.7]; moving to distance: 49.2
# Didn't satisfy criteria [dist=49.2]; moving to distance: 49.2
# Didn't satisfy criteria [dist=49.2]; moving to distance: 64.7
# Didn't satisfy criteria [dist=64.7]; moving to distance: 65.3
# Didn't satisfy criteria [dist=65.3]; moving to distance: 101.7
# Didn't satisfy criteria [dist=101.7]; moving to distance: 102.2
# Didn't satisfy criteria [dist=102.2]; moving to distance: 104.7
# Found what we're after! [dist=104.7; station=589680-99999]
# Finished with loc 166
# Didn't satisfy criteria [dist=24.2]; moving to distance: 62.4
# Found what we're after! [dist=62.4; station=983340-99999]
# Finished with loc 167
# Didn't satisfy criteria [dist=28.4]; moving to distance: 33.5
# Found what we're after! [dist=33.5; station=983340-99999]
# Finished with loc 168
# Didn't satisfy criteria [dist=51.9]; moving to distance: 53.3
# Didn't satisfy criteria [dist=53.3]; moving to distance: 54.3
# Didn't satisfy criteria [dist=54.3]; moving to distance: 81.7
# Found what we're after! [dist=81.7; station=766540-99999]
# Finished with loc 169
# Didn't satisfy criteria [dist=14.2]; moving to distance: 60.6
# Didn't satisfy criteria [dist=60.6]; moving to distance: 62.5
# Didn't satisfy criteria [dist=62.5]; moving to distance: 98.7
# Found what we're after! [dist=98.7; station=985480-99999]
# Finished with loc 170
# Didn't satisfy criteria [dist=37.0]; moving to distance: 44.8
# Didn't satisfy criteria [dist=44.8]; moving to distance: 46.3
# Didn't satisfy criteria [dist=46.3]; moving to distance: 72.2
# Didn't satisfy criteria [dist=72.2]; moving to distance: 84.8
# Didn't satisfy criteria [dist=84.8]; moving to distance: 86.1
# Didn't satisfy criteria [dist=86.1]; moving to distance: 98.8
# Didn't satisfy criteria [dist=98.8]; moving to distance: 127.2
# Didn't satisfy criteria [dist=127.2]; moving to distance: 129.3
# Didn't satisfy criteria [dist=129.3]; moving to distance: 134.0
# Found what we're after! [dist=134.0; station=916800-99999]
# Finished with loc 171
# Finished with loc 172
# Found what we're after! [dist=15.2; station=983340-99999]
# Finished with loc 173
# Found what we're after! [dist=24.5; station=982330-99999]
# Finished with loc 174
# Didn't satisfy criteria [dist=23.8]; moving to distance: 40.7
# Didn't satisfy criteria [dist=40.7]; moving to distance: 47.1
# Found what we're after! [dist=47.1; station=984440-99999]
# Finished with loc 175
# Didn't satisfy criteria [dist=16.2]; moving to distance: 32.2
# Didn't satisfy criteria [dist=32.2]; moving to distance: 33.0
# Didn't satisfy criteria [dist=33.0]; moving to distance: 45.6
# Found what we're after! [dist=45.6; station=943650-99999]
# Finished with loc 176
# Didn't satisfy criteria [dist=14.9]; moving to distance: 17.1
# Didn't satisfy criteria [dist=17.1]; moving to distance: 17.4
# Didn't satisfy criteria [dist=17.4]; moving to distance: 19.7
# Didn't satisfy criteria [dist=19.7]; moving to distance: 24.0
# Didn't satisfy criteria [dist=24.0]; moving to distance: 24.8
# Didn't satisfy criteria [dist=24.8]; moving to distance: 24.8
# Didn't satisfy criteria [dist=24.8]; moving to distance: 24.8
# Didn't satisfy criteria [dist=24.8]; moving to distance: 25.3
# Didn't satisfy criteria [dist=25.3]; moving to distance: 27.9
# Didn't satisfy criteria [dist=27.9]; moving to distance: 28.0
# Didn't satisfy criteria [dist=28.0]; moving to distance: 30.9
# Didn't satisfy criteria [dist=30.9]; moving to distance: 30.9
# Didn't satisfy criteria [dist=30.9]; moving to distance: 32.2
# Didn't satisfy criteria [dist=32.2]; moving to distance: 34.8
# Didn't satisfy criteria [dist=34.8]; moving to distance: 35.9
# Didn't satisfy criteria [dist=35.9]; moving to distance: 48.0
# Didn't satisfy criteria [dist=48.0]; moving to distance: 51.6
# Didn't satisfy criteria [dist=51.6]; moving to distance: 52.4
# Didn't satisfy criteria [dist=52.4]; moving to distance: 52.6
# Didn't satisfy criteria [dist=52.6]; moving to distance: 56.4
# Didn't satisfy criteria [dist=56.4]; moving to distance: 57.4
# Didn't satisfy criteria [dist=57.4]; moving to distance: 57.9
# Didn't satisfy criteria [dist=57.9]; moving to distance: 62.2
# Didn't satisfy criteria [dist=62.2]; moving to distance: 65.3
# Found what we're after! [dist=65.3; station=722510-12924]
# Finished with loc 177
# Didn't satisfy criteria [dist=44.1]; moving to distance: 46.9
# Didn't satisfy criteria [dist=46.9]; moving to distance: 48.2
# Didn't satisfy criteria [dist=48.2]; moving to distance: 50.8
# Didn't satisfy criteria [dist=50.8]; moving to distance: 52.2
# Didn't satisfy criteria [dist=52.2]; moving to distance: 53.1
# Didn't satisfy criteria [dist=53.1]; moving to distance: 58.7
# Didn't satisfy criteria [dist=58.7]; moving to distance: 60.0
# Didn't satisfy criteria [dist=60.0]; moving to distance: 62.0
# Didn't satisfy criteria [dist=62.0]; moving to distance: 62.2
# Didn't satisfy criteria [dist=62.2]; moving to distance: 64.4
# Didn't satisfy criteria [dist=64.4]; moving to distance: 65.9
# Didn't satisfy criteria [dist=65.9]; moving to distance: 71.9
# Didn't satisfy criteria [dist=71.9]; moving to distance: 73.2
# Didn't satisfy criteria [dist=73.2]; moving to distance: 76.4
# Didn't satisfy criteria [dist=76.4]; moving to distance: 77.0
# Didn't satisfy criteria [dist=77.0]; moving to distance: 78.1
# Didn't satisfy criteria [dist=78.1]; moving to distance: 84.4
# Didn't satisfy criteria [dist=84.4]; moving to distance: 86.9
# Didn't satisfy criteria [dist=86.9]; moving to distance: 88.3
# Didn't satisfy criteria [dist=88.3]; moving to distance: 90.9
# Didn't satisfy criteria [dist=90.9]; moving to distance: 93.8
# Didn't satisfy criteria [dist=93.8]; moving to distance: 97.9
# Didn't satisfy criteria [dist=97.9]; moving to distance: 101.1
# Didn't satisfy criteria [dist=101.1]; moving to distance: 102.5
# Didn't satisfy criteria [dist=102.5]; moving to distance: 104.0
# Didn't satisfy criteria [dist=104.0]; moving to distance: 104.3
# Found what we're after! [dist=104.3; station=722108-12894]
# Finished with loc 178
# Didn't satisfy criteria [dist=23.8]; moving to distance: 27.3
# Didn't satisfy criteria [dist=27.3]; moving to distance: 28.8
# Didn't satisfy criteria [dist=28.8]; moving to distance: 29.9
# Found what we're after! [dist=29.9; station=722108-12894]
# Finished with loc 179
# Didn't satisfy criteria [dist=2.6]; moving to distance: 9.0
# Didn't satisfy criteria [dist=9.0]; moving to distance: 35.7
# Didn't satisfy criteria [dist=35.7]; moving to distance: 39.5
# Didn't satisfy criteria [dist=39.5]; moving to distance: 46.6
# Didn't satisfy criteria [dist=46.6]; moving to distance: 46.6
# Didn't satisfy criteria [dist=46.6]; moving to distance: 47.6
# Didn't satisfy criteria [dist=47.6]; moving to distance: 49.6
# Didn't satisfy criteria [dist=49.6]; moving to distance: 49.6
# Didn't satisfy criteria [dist=49.6]; moving to distance: 49.6
# Didn't satisfy criteria [dist=49.6]; moving to distance: 52.1
# Didn't satisfy criteria [dist=52.1]; moving to distance: 52.2
# Didn't satisfy criteria [dist=52.2]; moving to distance: 55.0
# Didn't satisfy criteria [dist=55.0]; moving to distance: 55.0
# Didn't satisfy criteria [dist=55.0]; moving to distance: 57.3
# Didn't satisfy criteria [dist=57.3]; moving to distance: 57.8
# Didn't satisfy criteria [dist=57.8]; moving to distance: 67.9
# Didn't satisfy criteria [dist=67.9]; moving to distance: 68.8
# Didn't satisfy criteria [dist=68.8]; moving to distance: 70.2
# Didn't satisfy criteria [dist=70.2]; moving to distance: 70.6
# Didn't satisfy criteria [dist=70.6]; moving to distance: 71.7
# Didn't satisfy criteria [dist=71.7]; moving to distance: 76.0
# Didn't satisfy criteria [dist=76.0]; moving to distance: 76.0
# Didn't satisfy criteria [dist=76.0]; moving to distance: 91.9
# Didn't satisfy criteria [dist=91.9]; moving to distance: 100.2
# Didn't satisfy criteria [dist=100.2]; moving to distance: 104.2
# Didn't satisfy criteria [dist=104.2]; moving to distance: 110.0
# Didn't satisfy criteria [dist=110.0]; moving to distance: 110.4
# Didn't satisfy criteria [dist=110.4]; moving to distance: 110.4
# Didn't satisfy criteria [dist=110.4]; moving to distance: 110.8
# Didn't satisfy criteria [dist=110.8]; moving to distance: 119.9
# Didn't satisfy criteria [dist=119.9]; moving to distance: 119.9
# Didn't satisfy criteria [dist=119.9]; moving to distance: 121.8
# Didn't satisfy criteria [dist=121.8]; moving to distance: 122.0
# Didn't satisfy criteria [dist=122.0]; moving to distance: 122.4
# Didn't satisfy criteria [dist=122.4]; moving to distance: 123.0
# Didn't satisfy criteria [dist=123.0]; moving to distance: 123.1
# Didn't satisfy criteria [dist=123.1]; moving to distance: 126.3
# Didn't satisfy criteria [dist=126.3]; moving to distance: 129.3
# Didn't satisfy criteria [dist=129.3]; moving to distance: 130.1
# Didn't satisfy criteria [dist=130.1]; moving to distance: 134.4
# Didn't satisfy criteria [dist=134.4]; moving to distance: 135.1
# Didn't satisfy criteria [dist=135.1]; moving to distance: 135.1
# Didn't satisfy criteria [dist=135.1]; moving to distance: 141.3
# Didn't satisfy criteria [dist=141.3]; moving to distance: 141.7
# Didn't satisfy criteria [dist=141.7]; moving to distance: 143.0
# Didn't satisfy criteria [dist=143.0]; moving to distance: 151.3
# Didn't satisfy criteria [dist=151.3]; moving to distance: 151.8
# Didn't satisfy criteria [dist=151.8]; moving to distance: 151.8
# Didn't satisfy criteria [dist=151.8]; moving to distance: 216.0
# Finished with loc 180
# Didn't satisfy criteria [dist=28.0]; moving to distance: 30.6
# Didn't satisfy criteria [dist=30.6]; moving to distance: 30.6
# Didn't satisfy criteria [dist=30.6]; moving to distance: 31.2
# Didn't satisfy criteria [dist=31.2]; moving to distance: 32.1
# Didn't satisfy criteria [dist=32.1]; moving to distance: 32.7
# Didn't satisfy criteria [dist=32.7]; moving to distance: 32.7
# Didn't satisfy criteria [dist=32.7]; moving to distance: 32.7
# Didn't satisfy criteria [dist=32.7]; moving to distance: 33.2
# Didn't satisfy criteria [dist=33.2]; moving to distance: 41.3
# Didn't satisfy criteria [dist=41.3]; moving to distance: 42.3
# Didn't satisfy criteria [dist=42.3]; moving to distance: 43.2
# Didn't satisfy criteria [dist=43.2]; moving to distance: 43.8
# Didn't satisfy criteria [dist=43.8]; moving to distance: 44.0
# Didn't satisfy criteria [dist=44.0]; moving to distance: 51.1
# Didn't satisfy criteria [dist=51.1]; moving to distance: 51.2
# Didn't satisfy criteria [dist=51.2]; moving to distance: 51.2
# Didn't satisfy criteria [dist=51.2]; moving to distance: 59.4
# Didn't satisfy criteria [dist=59.4]; moving to distance: 61.5
# Didn't satisfy criteria [dist=61.5]; moving to distance: 61.7
# Didn't satisfy criteria [dist=61.7]; moving to distance: 64.9
# Didn't satisfy criteria [dist=64.9]; moving to distance: 65.4
# Didn't satisfy criteria [dist=65.4]; moving to distance: 78.0
# Didn't satisfy criteria [dist=78.0]; moving to distance: 81.3
# Didn't satisfy criteria [dist=81.3]; moving to distance: 93.5
# Didn't satisfy criteria [dist=93.5]; moving to distance: 94.7
# Didn't satisfy criteria [dist=94.7]; moving to distance: 95.8
# Didn't satisfy criteria [dist=95.8]; moving to distance: 100.5
# Didn't satisfy criteria [dist=100.5]; moving to distance: 100.5
# Didn't satisfy criteria [dist=100.5]; moving to distance: 100.6
# Didn't satisfy criteria [dist=100.6]; moving to distance: 103.6
# Didn't satisfy criteria [dist=103.6]; moving to distance: 104.1
# Didn't satisfy criteria [dist=104.1]; moving to distance: 105.9
# Didn't satisfy criteria [dist=105.9]; moving to distance: 115.8
# Didn't satisfy criteria [dist=115.8]; moving to distance: 129.9
# Didn't satisfy criteria [dist=129.9]; moving to distance: 136.1
# Didn't satisfy criteria [dist=136.1]; moving to distance: 136.4
# Didn't satisfy criteria [dist=136.4]; moving to distance: 136.4
# Didn't satisfy criteria [dist=136.4]; moving to distance: 147.5
# Didn't satisfy criteria [dist=147.5]; moving to distance: 151.6
# Didn't satisfy criteria [dist=151.6]; moving to distance: 156.6
# Didn't satisfy criteria [dist=156.6]; moving to distance: 157.1
# Didn't satisfy criteria [dist=157.1]; moving to distance: 157.1
# Didn't satisfy criteria [dist=157.1]; moving to distance: 158.7
# Didn't satisfy criteria [dist=158.7]; moving to distance: 160.1
# Didn't satisfy criteria [dist=160.1]; moving to distance: 163.3
# Didn't satisfy criteria [dist=163.3]; moving to distance: 166.5
# Didn't satisfy criteria [dist=166.5]; moving to distance: 176.6
# Didn't satisfy criteria [dist=176.6]; moving to distance: 177.2
# Didn't satisfy criteria [dist=177.2]; moving to distance: 184.4
# Didn't satisfy criteria [dist=184.4]; moving to distance: 232.1
# Finished with loc 181

# %% [markdown]
# ## Assess the impact of TC passage on the met recorded at these proximate weather stations

# %% [markdown]
# ### Start with the "gold standard": those stations close to TC landfall AND with long climatology

# %%
# Read in the metadata. All those TC landfall locations within maxdist of a (functioning) AWS are listed under
# "STATION_ID".
# We will take this list of functioning AWSs and further filter based on data availability over 
# the 1981-2010 period
metadata=pd.read_csv(outfile,delimiter="\t")
# Days between dates
st=datetime.date(year=1981,month=1,day=1); end=datetime.date(year=2010,month=12,day=31)
nd=(end-st).total_seconds()/(60**2*24.)+1
ncom=0 + len([ii for ii in os.listdir(odir) if ".csv" in ii])
for station in metadata["STATION_ID"]:
    if station + ".csv" not in os.listdir(odir):
        all,corevars=tc.get_gsod_data("/media/gytm3/WD12TB/GSOD",\
                [station,],startyr=int(1979), endyr=int(2017), \
                         parameters=["mean_temp","dew_point","sea_level_pressure"])
        corevars["tempC"]=GF.Faren2C(corevars["mean_temp"])
        corevars["dewC"]=GF.Faren2C(corevars["dew_point"])
        corevars.loc[corevars["mean_temp"]==9999.9,"tempC"]=np.nan
        corevars.loc[corevars["dew_point"]==9999.9,"dewC"]=np.nan
        corevars.loc[corevars["slp"]==9999.9,"slp"]=np.nan
        corevars["rh"]=GF.dewVp(corevars["dewC"]+273.15)/GF.satVp(corevars["tempC"])*100.            
        corevars["specHum"]=GF.specHum(corevars["tempC"],corevars["rh"],corevars["slp"])*1000. # g/kg
        
        corevars["hi"]=GF.HeatIndexNWS(corevars["tempC"],corevars["rh"],opt=False,iounit=np.array([0,0]))
        
        # Temporarily truncate and check for completion
        frac=np.sum(~np.isnan(corevars[st:end][["hi","slp"]].sum(axis=1)))/nd*100.
        print "station %s is %0.f%% complete" % (station,frac)
        if frac >= min_frac:
            ncom+=1
            corevars.to_csv(odir+station+".csv",float_format="%.2f"); print "written file: %.0f"%ncom
# Out:
# station 722500-12919 is 100% complete
# written file: 1
# station 595590-99999 is 99% complete
# written file: 2
# station 983280-99999 is 98% complete
# written file: 3
# station 982230-99999 is 96% complete
# written file: 4
# station 467610-99999 is 56% complete
# written file: 5
# station 984400-99999 is 96% complete
# written file: 6
# station 766440-99999 is 100% complete
# written file: 7
# station 785350-11630 is 85% complete
# written file: 8
# station 722080-13880 is 100% complete
# written file: 9
# station 478430-99999 is 100% complete
# written file: 10
# station 478170-99999 is 100% complete
# written file: 11
# station 477620-99999 is 99% complete
# written file: 12
# station 722020-12839 is 100% complete
# written file: 13
# station 911650-22536 is 100% complete
# written file: 14
# station 982330-99999 is 81% complete
# written file: 15
# station 478360-99999 is 99% complete
# written file: 16
# station 478290-99999 is 59% complete
# written file: 17
# station 467660-99999 is 58% complete
# written file: 18
# station 467060-99999 is 54% complete
# written file: 19
# station 943050-99999 is 54% complete
# written file: 20
# station 747770-03852 is 79% complete
# written file: 21
# station 984440-99999 is 95% complete
# written file: 22
# station 984290-99999 is 100% complete
# written file: 23
# station 943120-99999 is 99% complete
# written file: 24
# station 943060-99999 is 63% complete
# written file: 25
# station 479120-99999 is 57% complete
# written file: 26
# station 428090-99999 is 99% complete
# written file: 27
# station 943020-99999 is 99% complete
# written file: 28
# station 943000-99999 is 100% complete
# written file: 29
# station 478380-99999 is 60% complete
# written file: 30
# station 942030-99999 is 98% complete
# written file: 31
# station 593580-99999 is 99% complete
# written file: 32
# station 943100-99999 is 42% complete
# station 943100-99999 is 42% complete
# station 915900-99999 is 99% complete
# written file: 33
# station 471680-99999 is 100% complete
# written file: 34
# station 915540-99999 is 95% complete
# written file: 35
# station 953170-99999 is 26% complete
# station 953170-99999 is 26% complete
# station 984460-99999 is 75% complete
# written file: 36
# station 722106-12835 is 100% complete
# written file: 37
# station 478090-99999 is 59% complete
# written file: 38
# station 747686-99999 is 23% complete
# station 747686-99999 is 23% complete
# station 747686-99999 is 23% complete
# station 994260-99999 is 79% complete
# written file: 39
# station 591580-99999 is 99% complete
# written file: 40
# station 941390-99999 is 40% complete
# station 983300-99999 is 49% complete
# station 953170-99999 is 26% complete
# station 478270-99999 is 100% complete
# written file: 41
# station 670950-99999 is 92% complete
# written file: 42
# station 589680-99999 is 99% complete
# written file: 43
# station 943100-99999 is 42% complete
# station 952860-99999 is 27% complete
# station 982320-99999 is 76% complete
# written file: 44
# station 943100-99999 is 42% complete
# station 943100-99999 is 42% complete
# station 724070-93730 is 100% complete
# written file: 45
# station 987550-99999 is 72% complete
# written file: 46
# station 983340-99999 is 28% complete
# station 985380-99999 is 90% complete
# written file: 47
# station 984270-99999 is 86% complete
# written file: 48
# station 597580-99999 is 100% complete
# written file: 49
# station 985530-99999 is 32% complete
# station 941400-99999 is 64% complete
# written file: 50
# station 953700-99999 is 17% complete
# station 953700-99999 is 17% complete
# station 983340-99999 is 28% complete
# station 983340-99999 is 28% complete
# station 766540-99999 is 83% complete
# written file: 51
# station 985480-99999 is 86% complete
# written file: 52
# station 916800-99999 is 100% complete
# written file: 53
# station 983340-99999 is 28% complete
# station 943650-99999 is 48% complete
# station 722510-12924 is 100% complete
# written file: 54
# station 722108-12894 is 17% complete
# station 722108-12894 is 17% complete

# %%
# Read in the met files saved in odir and compute DoY climatology (1981-2010 only). 
# Computing the kernels takes some time, so be patient!
reload(tc)
files=[ii for ii in os.listdir(odir) if ".csv" in ii and "lock" not in ii]
station={}
st=datetime.datetime(year=1981,month=1,day=1); end=datetime.datetime(year=2010,month=12,day=31)
for f in files:
    name=f.strip(".csv")
    station[name]=pd.read_csv(odir+f,index_col=0,parse_dates=True)
    
    # Compute JD from datetime
    idx=np.logical_and(station[name].index>=st,station[name].index<=end)
    station[name]["doy"]=station[name].index.dayofyear
    
    # Run kernels
    mu,fn,station[name]["clim_hi"]=\
    tc.kernel_smooth_doy(station[name]["hi"][idx],station[name]["doy"][idx],station[name]["doy"],stdev)
    
    mu,fn,station[name]["clim_temp"]=\
    tc.kernel_smooth_doy(station[name]["tempC"][idx],station[name]["doy"][idx],station[name]["doy"],stdev)
    
    mu,fn,station[name]["clim_specHum"]=\
    tc.kernel_smooth_doy(station[name]["specHum"][idx],station[name]["doy"][idx],station[name]["doy"],stdev)
    
    mu,fn,station[name]["clim_slp"]=\
    tc.kernel_smooth_doy(station[name]["slp"][idx],station[name]["doy"][idx],station[name]["doy"],stdev)
    
    # Store anomalies
    station[name]["hi_anom"]=station[name]["hi"]-station[name]["clim_hi"]
    station[name]["temp_anom"]=station[name]["tempC"]-station[name]["clim_temp"]
    station[name]["specHum_anom"]=station[name]["specHum"]-station[name]["clim_specHum"]
    station[name]["slp_anom"]=station[name]["slp"]-station[name]["clim_slp"]
# Dump all
pickle.dump(station,open(odir+"Anoms.p","wb"))

# %%
f
# Out:
# '.~lock.595590-99999.csv#'

# %%
# Now we are going to extract the periods of TC landfall (+/- 30 days)
meta=pd.read_csv(outfile,delimiter="\t") # re-open metadata
station = pickle.load( open( odir+"Anoms.p", "rb" ) )
locsin=station.keys()
hi_anom=np.zeros((61,len(meta)))
temp_anom=np.zeros(hi_anom.shape)*np.nan
hum_anom=np.zeros(hi_anom.shape)*np.nan
slp_anom=np.zeros(hi_anom.shape)*np.nan
nsuc=0
storm_id=[]
processed={}
for ii in range(len(metadata)):
    if meta["STATION_ID"][ii] not in  locsin:
        continue
    # Construct date index for this landfall location
    tc_date=datetime.date(year=int(meta["YEAR"][ii]),month=int(meta["MONTH"][ii]),\
                          day=int(meta["DAY"][ii]))
    tc_st=tc_date-datetime.timedelta(days=30)
    tc_end=tc_date+datetime.timedelta(days=30)
    string_st="%.0f-%02d-%02d" % (tc_st.year,tc_st.month,tc_st.day)
    string_end="%.0f-%02d-%02d" % (tc_end.year,tc_end.month,tc_end.day)
    
    # Store the anoms for TC +/- 30 days
    hi_anom[:,nsuc]=station[meta["STATION_ID"][ii]][string_st:string_end]["hi_anom"]
    temp_anom[:,nsuc]=station[meta["STATION_ID"][ii]][string_st:string_end]["temp_anom"]
    hum_anom[:,nsuc]=station[meta["STATION_ID"][ii]][string_st:string_end]["specHum_anom"]
    slp_anom[:,nsuc]=station[meta["STATION_ID"][ii]][string_st:string_end]["slp_anom"]
    storm_id.append(meta["ID"][ii])
    
    # Need to remove duplicate AWS data (when the same station is used for multiple landfall locations at the same
    # time)
    if meta["STATION_ID"][ii] in processed.keys(): 
        if processed[meta["STATION_ID"][ii]][0]==meta["YEAR"][ii] and \
        processed[meta["STATION_ID"][ii]][1]==meta["MONTH"][ii] and \
        processed[meta["STATION_ID"][ii]][2]==meta["DAY"][ii]:
            
            hi_anom[:,nsuc]=np.nan; temp_anom[:,nsuc]=np.nan; hum_anom[:,nsuc]=np.nan; slp_anom[:,nsuc]=np.nan 
            continue
    else:
        processed[meta["STATION_ID"][ii]]=[meta["YEAR"][ii],meta["MONTH"][ii],meta["DAY"][ii]]
        
        
    nsuc+=1; 
#print len(np.unique(storm_id))

# %%
# Now summarise the profile - noting that nsuc gives us the number of members in our sample
fig,ax=plt.subplots(2,2)
x=range(-30,31)
vs=[temp_anom[:,:nsuc],hum_anom[:,:nsuc],hi_anom[:,:nsuc],slp_anom[:,:nsuc]]
denom=np.sqrt(nsuc)
count=0
for v in vs:
    mu=np.mean(v,axis=1)
    std=np.std(v,axis=1)
    sterr=std/denom
    ax.flat[count].fill_between(x,mu-sterr,mu+sterr,color="grey",alpha=0.25)
    ax.flat[count].plot(x,mu,color="k")
    ax.flat[count].axhline(0,color="red")
    count+=1; print count
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Silver Standard: AWSs logging HI only during TC passage (next 30 days)

# %%
# Use ulmo-modified code to extract met data for the station nearest the TC landfall
reload(tc)
ids=all_stations.keys() # station codes
latlon=np.array([[all_stations[ii]["latitude"],all_stations[ii]["longitude"]] for ii in ids],dtype=np.float) # coordinates
# Test now by extracting pressure 
outmet=[]
outmet_hit=[]
out_station=[]
out_pickle={}
dist_used=np.zeros((len(tcdata)))*np.nan
nsuc=0
with open(outfile_silver,"w") as fo:
    
    # Write the header to the output file
    fo.write("YEAR\tMONTH\tDAY\tID\tLAT\tLON\tSTATION_ID\tDIST\n")
    
    for loc in range(len(tcdata)):

        # If all criteria are met, we'll not search any more; initialise to "search"
        dist=GF.haversine_fast(tclat[loc],tclon[loc],latlon[:,0],latlon[:,1],miles=False) # that's the distance
        order=np.argsort(dist)
        nearest=0
        mindist=dist[order[nearest]]
        keep_search=True
        while keep_search and mindist<maxdist:

            # Construct date index for this landfall location
            # Note that in creating tc_date we range from 1 day after landfall (1st jan + JD_days = st_date+1)
            tc_date=datetime.date(year=int(tcdata[loc,1]),month=1,day=1)+\
            datetime.timedelta(days=np.floor(tcdata[loc,2]))
            tc_end=tc_date+datetime.timedelta(days=29)

            # Now extract all data for the year (+/-1) of TC landfall for the station closest to landfall location
            startyr=tc_date.year-1; endyr=tc_date.year+1
            alldata,corevars=tc.get_gsod_data("/media/gytm3/WD12TB/GSOD",\
            [ids[order[nearest]],],startyr=int(startyr), endyr=int(endyr), parameters=None)

            # Check we have something!
            if len(corevars)>1:     

                # Compute HI. etc
                corevars["tempC"]=GF.Faren2C(corevars["mean_temp"])
                corevars["dewC"]=GF.Faren2C(corevars["dew_point"])
                # Set to nan
                corevars.loc[corevars["mean_temp"]==9999.9,"tempC"]=np.nan
                corevars.loc[corevars["dew_point"]==9999.9,"dewC"]=np.nan
                corevars.loc[np.logical_or(corevars["slp"]==9999.9,corevars["slp"]<800),"slp"]=np.nan
                corevars["rh"]=GF.dewVp(corevars["dewC"]+273.15)/GF.satVp(corevars["tempC"])*100.            
                corevars["specHum"]=GF.specHum(corevars["tempC"],corevars["rh"],corevars["slp"])
                corevars["hi"]=GF.HeatIndexNWS(corevars["tempC"],corevars["rh"],opt=False,iounit=np.array([0,0]))

                # Check for completion during "hit"
                hit_data=corevars[tc_date:tc_end]

                # Examine hi availability 
                n_hi=len(hit_data["hi"])

                # Then all data here
                if np.sum(~np.isnan(hit_data["hi"]))==30:
                    outmet.append(corevars)
                    outmet_hit.append(hit_data)
                    dist_used[loc]=dist[order[nearest]]
                    out_station.append(ids[order[nearest]])
                    
                    
                    # **********************************************************
                    # Save the met data in a dictionary: key = tc_id-date; 
                    # entry = [station id, station lat, station lon, 31 day HI ]
                    # ********************************************************** 

                    key_date=tc_date-datetime.timedelta(days=1) # shift back by one day for landfall
                    key="%.0f_%.0f-%02d-%02d" %(tcdata[loc,0],key_date.year,key_date.month,key_date.day)
                    
                    out_pickle[key]\
                    =[ids[order[nearest]],all_stations[ids[order[nearest]]]["latitude"],\
                      all_stations[ids[order[nearest]]]["longitude"],hit_data["hi"].values]
                    
                    
                    hit_data.to_csv(odir_silver\
                    +key+".csv",float_format="%.4f"); print "written file: %.0f!" % nsuc
                    
                    # Also figure out the max HI as we pass! 
                    maxhi=hit_data["hi"].max()
                    if maxhi>40.6:
                        print "\n***\nTC %.0f exceeded 40.6C!\n***\n" % tcdata[loc,0]
                    
                    # End search
                    keep_search=False; print "Found what we're after! [dist=%.1f; station=%s]" \
                    % (dist[order[nearest]],ids[order[nearest]])
                    nsuc+=1
                    
                    # Write a new line out
                    lout="%.0f\t%.0f\t%.0f\t%.0f\t%.2f\t%.2f\t%s\t%.2f\n" % \
                    (tc_date.year,tc_date.month,tc_date.day,\
                     tcdata[loc,0],tcdata[loc,3],tcdata[loc,4],ids[order[nearest]],dist[order[nearest]])
                    fo.write(lout); fo.flush()

            if keep_search:
                mindist=dist[order[nearest+1]]
                print "Didn't satisfy criteria [dist=%.1f; nhi=%.0f]; moving to distance: %.1f" % \
                    (dist[order[nearest]],n_hi,mindist)


            nearest+=1  
        print "Finished with loc %.0f" % loc
        
# Pickle all these station data
pickle.dump(out_pickle,open("StationData_PostTC.p","wb"))

# %%
key
# Out:
# '9214_1980-11-04'

# %% [markdown]
# Now, with this "silver" output written to file (HI in 30-days following landfall), compare to the HI as estimated
# by WFDEI.
#
# The method here is to iterate over the netcdf WFDEI file, in which each location is the main dimension; time, latitude and longitude are parallel dimensions.

# %%
# Number of days after TC we're interested in...
ndays=30  


# Define WFDEI data
metfile="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/TC_met_all.nc"
meto=Dataset(metfile,"r")

# Define NCEP data
metfile_ncep="/media/gytm3/WD12TB/TropicalCyclones/TC-DeadlyHeat/Data/NCEP_II_TC_met_all.nc"
meto_ncep=Dataset(metfile_ncep,"r")

# Get ntime and nlocs
ntime,nlocs=meto.variables["hi"].shape
time=meto.variables["time"]
yr,mon,day,hr,dt=\
GF.conTimes(time_str=time.units,calendar="standard",\
                    times=time[:],safe=False)
grid_times=np.floor(tc.dt2decday(dt)) # decimal time (WFDEI)

# Read in the pickled AWS data
# structure: {tcid_yy-mm-dd: [station id, lat, lon, 31 values]
aws_data=pickle.load(open("StationData_PostTC.p","rb"))
aws_keys=aws_data.keys()


# Make substitutions for clearer code
tc_yy=tcdata[:,1]
tc_jd=np.floor(tcdata[:,2])
nim=0
hi_out=np.zeros((nlocs,ndays))
hi_out_pop=np.zeros((nlocs,3))
tcid=tcdata[:,0]
comp=np.zeros((len(tcdata),6))
stdvs=np.zeros((len(tcdata),2))
nmatch=0
for ll in range(nlocs):
        
        
        #if tc_yy[ll]==2017 and tc_jd[ll]>(365-ndays): continue # because ndays window will trigger an 
            # out-of-bounds error
            
        if (tc_yy[ll]>=2015 and tc_jd[ll]>(365-ndays)) or tc_yy[ll]>2015: continue
        
        # Get time index in nc file - based on time in tcdata (of landfall)
        idx=np.logical_and(yr==tcdata[ll,1],np.logical_and(grid_times>=tc_jd[ll]+1,grid_times<=tc_jd[ll]+ndays))
        n=np.sum(idx)
        
        if n <ndays: # then we need to "wrap" around to the BEGINNING of the NEXT year
            idx=np.logical_or(idx,np.logical_and(yr==tcdata[ll,1]+1,grid_times<=ndays-n))
            
        # Store raw hi series
        hi_out[ll,:]=meto.variables["hi"][idx,ll]
        
        # Check that we're reading the right TC!
        assert meto.variables["id"][ll]==tcdata[ll,0]
        
        # Create datetime object of time of landfall
        tc_date=datetime.date(year=int(tcdata[ll,1]),month=1,day=1)+\
            datetime.timedelta(days=np.floor(tcdata[ll,2])-1)
        
        # Now retrieve the AWS data using the id_yy-mm-dd as the key
        
        key = "%.0f_%.0f-%02d-%02d"%(tcdata[ll,0], tc_date.year,tc_date.month,tc_date.day)
        if key in aws_keys: 
            aws_ii = aws_data[key]
            
            # Open the .csv file with the full aws met info
            test=pd.read_csv(odir_silver+key+".csv",index_col=0,parse_dates=True)
            
            # Check alignment of dates
            assert test.index[0].to_pydatetime().date()==dt[idx][0].date()
            
            # Put in grid data for comparisons/correlations
            test["grid_tempC"]=meto.variables["Tair"][idx,ll]-273.15
            test["grid_rh"]=meto.variables["Qair"][idx,ll]/GF.specHum(meto.variables["Tair"][idx,ll],\
                                                      np.ones(30)*100,\
                                                      meto.variables["PSurf"][idx,ll])*100
            test["grid_press"]=meto.variables["PSurf"][idx,ll]/100.
            test["grid_hi"]=meto.variables["hi"][idx,ll]
            
            # Add ncep data
            test["ncep_grid_tempC"]=meto_ncep.variables["Tair"][idx,ll]-273.15
            test["ncep_grid_rh"]=meto_ncep.variables["Qair"][idx,ll]/GF.specHum(meto.variables["Tair"][idx,ll],\
                                                      np.ones(30)*100,\
                                                      meto.variables["PSurf"][idx,ll])*100
            test["ncep_grid_press"]=meto_ncep.variables["PSurf"][idx,ll]/100.
            test["ncep_grid_hi"]=meto_ncep.variables["hi"][idx,ll]            
            
            # Compute all correlations: 
            rs=test.corr()

            
            # Perform correlations etc
            comp[nmatch,0]=rs["hi"]["grid_hi"]
            comp[nmatch,1]=rs["slp"]["grid_press"]
            comp[nmatch,2]=test["slp"].mean()-test["grid_press"].mean()
            comp[nmatch,3]=GF.haversine((tcdata[ll,5],tcdata[ll,6]), (aws_ii[1],aws_ii[2]), miles=False)
            comp[nmatch,4]=rs["hi"]["ncep_grid_hi"]
            comp[nmatch,5]=rs["grid_hi"]["ncep_grid_hi"]
            #comp[nmatch,4]=meto.variables["stdv"][ll]
                    
            
            # Bad matches
            if comp[nmatch,0]<0.25: # then BIG rmse, and we should inspect the files...

                test.to_csv(testdir+"bad_"+key+".csv",float_format="%.4f")
                            
            # Goodp matches
            if comp[nmatch,0]>0.75:

                test.to_csv(testdir+"good_"+key+".csv",float_format="%.4f")

            
            nmatch+=1
        nim+=1      
        
                     
# Truncate as necessary
hi_out=hi_out[:nim,:]
comp=comp[:nmatch,:]
#print np.nanmean(comp[:,1]), np.max(comp[:,-1])
stdvs=stdvs[:nmatch,:]
#plt.scatter(comp[:,-1],comp[:,1]) 
#plt.scatter(comp[:,-1],comp[:,0])

# print means for WFDEI and NCEP hi
print "NCEP:",np.nanmean(comp[:,4]),"WFDEI:",np.nanmean(comp[:,0])
print "NCEP/WFDEI:",np.nanmean(comp[:,5])
# Out:
# NCEP: 0.4517361783028493 WFDEI: 0.6051830799940643
# NCEP/WFDEI: 0.5205495519857826

# %% [markdown]
# Notes: there is very low correlation (and high RMSE) for quite a few stations. We need to try to figure out whether this is due to a data processing error, or if it reflects some sort of limitation in the WFDEI data...
#
# So far:
#
# - the raw data look to be sensible (inspection of individual files based on low r)
#
# next:
# - repeat for high RMSE (>10 C)
# - explore if corrrelation error is f(var)

# %%
rs
# Out:
#                  dew_point  mean_temp       slp     tempC      dewC        rh  \
# dew_point         1.000000   0.756127 -0.315401  0.756120  1.000000  0.386222
# mean_temp         0.756127   1.000000 -0.160920  1.000000  0.756126 -0.311317
# slp              -0.315401  -0.160920  1.000000 -0.160910 -0.315401 -0.233251
# tempC             0.756120   1.000000 -0.160910  1.000000  0.756119 -0.311326
# dewC              1.000000   0.756126 -0.315401  0.756119  1.000000  0.386223
# rh                0.386222  -0.311317 -0.233251 -0.311326  0.386223  1.000000
# specHum           0.999162   0.753224 -0.325932  0.753217  0.999162  0.388749
# hi                0.856929   0.978334 -0.194482  0.978331  0.856928 -0.135637
# grid_tempC        0.510424   0.691267  0.045148  0.691268  0.510427 -0.239347
# grid_rh           0.302613  -0.084080  0.000099 -0.084082  0.302611  0.567244
# grid_press       -0.245827  -0.130624  0.948470 -0.130614 -0.245829 -0.170994
# grid_hi           0.711377   0.754310  0.087590  0.754310  0.711380 -0.034290
# ncep_grid_tempC   0.626809   0.691298 -0.059216  0.691303  0.626814 -0.063878
# ncep_grid_rh     -0.032410  -0.323893  0.214988 -0.323895 -0.032409  0.419754
# ncep_grid_press  -0.187640   0.049548  0.780252  0.049559 -0.187641 -0.345451
# ncep_grid_hi      0.451654   0.503141 -0.057681  0.503147  0.451662 -0.052273
#
#                   specHum        hi  grid_tempC   grid_rh  grid_press  \
# dew_point        0.999162  0.856929    0.510424  0.302613   -0.245827
# mean_temp        0.753224  0.978334    0.691267 -0.084080   -0.130624
# slp             -0.325932 -0.194482    0.045148  0.000099    0.948470
# tempC            0.753217  0.978331    0.691268 -0.084082   -0.130614
# dewC             0.999162  0.856928    0.510427  0.302611   -0.245829
# rh               0.388749 -0.135637   -0.239347  0.567244   -0.170994
# specHum          1.000000  0.857063    0.518187  0.286734   -0.257625
# hi               0.857063  1.000000    0.706050 -0.022582   -0.155425
# grid_tempC       0.518187  0.706050    1.000000 -0.497416    0.039518
# grid_rh          0.286734 -0.022582   -0.497416  1.000000    0.039908
# grid_press      -0.257625 -0.155425    0.039518  0.039908    1.000000
# grid_hi          0.712975  0.798601    0.901054 -0.084076    0.082912
# ncep_grid_tempC  0.623287  0.704107    0.553146  0.027451    0.041289
# ncep_grid_rh    -0.045588 -0.291714   -0.536313  0.745792    0.176321
# ncep_grid_press -0.193453  0.001506    0.301320 -0.271532    0.856022
# ncep_grid_hi     0.446771  0.505529    0.405942  0.049898    0.025737
#
#                   grid_hi  ncep_grid_tempC  ncep_grid_rh  ncep_grid_press  \
# dew_point        0.711377         0.626809     -0.032410        -0.187640
# mean_temp        0.754310         0.691298     -0.323893         0.049548
# slp              0.087590        -0.059216      0.214988         0.780252
# tempC            0.754310         0.691303     -0.323895         0.049559
# dewC             0.711380         0.626814     -0.032409        -0.187641
# rh              -0.034290        -0.063878      0.419754        -0.345451
# specHum          0.712975         0.623287     -0.045588        -0.193453
# hi               0.798601         0.704107     -0.291714         0.001506
# grid_tempC       0.901054         0.553146     -0.536313         0.301320
# grid_rh         -0.084076         0.027451      0.745792        -0.271532
# grid_press       0.082912         0.041289      0.176321         0.856022
# grid_hi          1.000000         0.641156     -0.258511         0.224352
# ncep_grid_tempC  0.641156         1.000000     -0.206050         0.145499
# ncep_grid_rh    -0.258511        -0.206050      1.000000        -0.251986
# ncep_grid_press  0.224352         0.145499     -0.251986         1.000000
# ncep_grid_hi     0.492512         0.914909     -0.063350         0.053479
#
#                  ncep_grid_hi
# dew_point            0.451654
# mean_temp            0.503141
# slp                 -0.057681
# tempC                0.503147
# dewC                 0.451662
# rh                  -0.052273
# specHum              0.446771
# hi                   0.505529
# grid_tempC           0.405942
# grid_rh              0.049898
# grid_press           0.025737
# grid_hi              0.492512
# ncep_grid_tempC      0.914909
# ncep_grid_rh        -0.063350
# ncep_grid_press      0.053479
# ncep_grid_hi         1.000000

# %%
comp[nmatch-1,1]
# Out:
# 2.157507640300983

# %%
dt[idx][0].date()
# Out:
# datetime.date(1980, 11, 5)

# %%
comp[:,1]
# Out:
# array([0.92817924, 0.91650818, 0.91322469, 0.9851781 , 0.99495339,
#        0.98458259, 0.97737927, 0.87252139, 0.98138062, 0.94460368,
#        0.95629671, 0.94941602, 0.98293742, 0.95611458, 0.97106665,
#        0.91599396, 0.70129011, 0.98776799,        nan,        nan,
#        0.88852802,        nan,        nan,        nan, 0.99076992,
#        0.99567998, 0.59852508, 0.8952813 , 0.94379799, 0.98841191,
#        0.99126389, 0.90180635, 0.89713253, 0.99354485, 0.98887046,
#        0.99393727, 0.96917292, 0.91583188, 0.98839221, 0.96361734,
#        0.97840644, 0.98563948, 0.981756  , 0.92449613, 0.93309701,
#        0.90358374,        nan, 0.92966093, 0.96385833, 0.98499576,
#        0.9447489 , 0.96212425, 0.97744157, 0.98722868, 0.97950958,
#        0.98321205, 0.9924881 , 0.97912317, 0.9946425 , 0.99444856,
#        0.83936985, 0.84020047, 0.98659492, 0.98723472, 0.98220469,
#        0.98663682, 0.9793026 , 0.98091324, 0.98616903, 0.8999523 ,
#        0.99336968, 0.98773837, 0.97245652, 0.97240395,        nan,
#               nan, 0.92227065, 0.98047963, 0.98219421, 0.98136688,
#               nan, 0.99616055, 0.92446024,        nan, 0.98532424,
#        0.98303889, 0.95159577, 0.96937812, 0.96658337, 0.95655778,
#               nan, 0.96934493, 0.91549812, 0.91211319, 0.75638665,
#        1.        , 0.99198002,        nan,        nan, 0.94275617,
#        0.97858764, 0.96638553, 0.98948165,        nan, 0.95690265,
#        0.88847997, 0.99573098, 0.99191209, 0.99536215, 0.96665212,
#        0.97505216, 0.98415126, 0.88843857, 0.91936855, 0.96877486,
#        0.95818156, 0.99484271,        nan,        nan, 0.97470788,
#        0.97838285, 0.99536801, 0.99170658, 0.94228876, 0.98092051,
#        0.99136029, 0.94847002])
